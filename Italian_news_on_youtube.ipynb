# %%
# !pip install --upgrade google-api-python-client
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (2.56.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.31.6)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.56.4)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.15.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.17.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.23.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (57.4.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.0.4)

# %%
import matplotlib.pyplot as plt

# %%
api_key = '***'
channel_ids = ['UCmoMxFxfjHJIicCv1eV_tSA', #tgcom24
               'UC9ePmjVRHLL8x8vq5fOKflg', # la repubblica
               'UCB3e_9sPf7whZA4PfGXrIMQ', # quotidiano nazionale
               'UCCuZicOOisRgknWUSQArudg', # sole24h
               'UCWJhBqnyVdHAuxexgjghNFw', # fanpage
               'UCPfFXhCgc6cciu3aYm-9AdA'# fattoquotidiano
               
               
               
              
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_statistics
# Out:
# [{'Channel_name': 'La Repubblica',
#   'Subscribers': '692000',
#   'Total_videos': '29519',
#   'Views': '680050335',
#   'playlist_id': 'UU9ePmjVRHLL8x8vq5fOKflg'},
#  {'Channel_name': 'QuotidianoNazionale',
#   'Subscribers': '187000',
#   'Total_videos': '15381',
#   'Views': '98658624',
#   'playlist_id': 'UUB3e_9sPf7whZA4PfGXrIMQ'},
#  {'Channel_name': 'Tgcom24',
#   'Subscribers': '86000',
#   'Total_videos': '3793',
#   'Views': '54184417',
#   'playlist_id': 'UUmoMxFxfjHJIicCv1eV_tSA'},
#  {'Channel_name': 'Il Fatto Quotidiano',
#   'Subscribers': '374000',
#   'Total_videos': '21092',
#   'Views': '185005130',
#   'playlist_id': 'UUPfFXhCgc6cciu3aYm-9AdA'},
#  {'Channel_name': 'Fanpage.it',
#   'Subscribers': '2810000',
#   'Total_videos': '31719',
#   'Views': '2547723544',
#   'playlist_id': 'UUWJhBqnyVdHAuxexgjghNFw'},
#  {'Channel_name': 'Il Sole 24 ORE',
#   'Subscribers': '113000',
#   'Total_videos': '30647',
#   'Views': '67788887',
#   'playlist_id': 'UUCuZicOOisRgknWUSQArudg'}]

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#           Channel_name Subscribers       Views Total_videos  \
# 0        La Repubblica      692000   680050335        29519
# 1  QuotidianoNazionale      187000    98658624        15381
# 2              Tgcom24       86000    54184417         3793
# 3  Il Fatto Quotidiano      374000   185005130        21092
# 4           Fanpage.it     2810000  2547723544        31719
# 5       Il Sole 24 ORE      113000    67788887        30647
#
#                 playlist_id
# 0  UU9ePmjVRHLL8x8vq5fOKflg
# 1  UUB3e_9sPf7whZA4PfGXrIMQ
# 2  UUmoMxFxfjHJIicCv1eV_tSA
# 3  UUPfFXhCgc6cciu3aYm-9AdA
# 4  UUWJhBqnyVdHAuxexgjghNFw
# 5  UUCuZicOOisRgknWUSQArudg

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %% [markdown]
# # Channels subscribers

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %% [markdown]
# # Channels views

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %% [markdown]
# # Channels total videos

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %% [markdown]
# #Focus on the channel with most views and subscribers

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Fanpage.it', 'playlist_id'].iloc[0]

# %% [markdown]
# ## Function to get video ids

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['TugSVm7Upt0',
#  '6leNU8b7K08',
#  'nRsEsKvrCoc',
#  'ooKRY1MpyYM',
#  'VZqxnXNge9s',
#  'OE2dBNoHnsc',
#  '2ued45O1dsw',
#  'KU3EmgS9QVY',
#  'KIOhJ08ReZk',
#  '7O9kGnyq1H0',
#  'JBjtYdWeBNc',
#  'PwqYwbcjVnw',
#  'pwNUWvyNzQ4',
#  'Kjg4ywwiI-0',
#  'XaNr0B6Fmfw',
#  'ZUeFhoJ9QRc',
#  '-V-qfE_DMLw',
#  'nPiZJ9_wICY',
#  '4-FXvQ7mONM',
#  'p-VDII7h-cM',
#  'Ur1RkmeBDCQ',
#  'NUWkqy5tBVc',
#  'LbP0Rq77KvI',
#  'ZoRVC7e-_n8',
#  'Bpfq371qWGE',
#  'jvKIFpDpKXE',
#  'IhWu77FtpsQ',
#  'i9YOoro2jQw',
#  'QVbTRVrr7QI',
#  'OkizJrExZdI',
#  'QjlMM2KpmCQ',
#  'oDTdIlOPw3M',
#  'ZckCsB12sLM',
#  'cCbq5mMeFP8',
#  'Xsfj8Al85zw',
#  'f3dw6bGsqeQ',
#  'IMcieSRjPZI',
#  '8jy5ElUMBXk',
#  '8gcaMTnKNAo',
#  'O0gGY2iNx3Q',
#  'vtOtsc_KJ4I',
#  'hfzSctVfR38',
#  'CeRhG6jKJQo',
#  'rgI7Wyty7nI',
#  'wYT-udNvEPk',
#  '8ePlrtYoxCA',
#  'xmz1QwfIfpk',
#  'ij0nTHnNhfI',
#  'OOdEVCZYjuU',
#  'Azpt0fgjXrE',
#  'eZpSebkHR0U',
#  '-Ov8M4CApIg',
#  'TLwJ0emyH5Y',
#  '4dZsgxOgjM4',
#  'z6qmztpDxDY',
#  'DmFvX979vNk',
#  '5vi1vEtIB4g',
#  'peTIW5fZAJQ',
#  'aDaFpipyNSY',
#  'ipEIqYICwI0',
#  'jIDXhtACFCY',
#  '-5CoctR_Zvs',
#  'xt2JVkhE_iY',
#  '-PFTyBPsx54',
#  'Rtaa6vHVJPI',
#  'VaU_F0A8494',
#  '4ZhgnuFlmNg',
#  'Fy_XwkAFCcQ',
#  'YVSyqkNHvwM',
#  'vLhttJz6tlU',
#  '50nxgn2Knyo',
#  'NWnozsS0Jrw',
#  'pOFYuTsitlw',
#  'tAHozPqTvtk',
#  'TdcphcGL0LE',
#  'm94vwBq0NHg',
#  'PfGe02ySmv4',
#  '_5bLjyK8xVQ',
#  'EDkkFIJ_w3w',
#  '1S3sv14nQzc',
#  'wvPlSCuH-Tw',
#  'zHOSnitarwA',
#  'T9P9NgVfWfg',
#  '4611ILRRLuM',
#  'z40vL84WJKs',
#  'BOxU-MowLKc',
#  'RvshG_gjbwo',
#  'vMlhnn24PF0',
#  'hyJXCdsy8e0',
#  'qjGFgMeohrU',
#  'EFFin_d0laM',
#  'kcKaeSSTt_Q',
#  'D4Odcm_gGKI',
#  'co4JKfrzsfM',
#  'aiV30e8ndXk',
#  'Pom32qmSugg',
#  '9OyPjiOpOig',
#  'EXyvD05Bsw0',
#  'a8J2xUcookA',
#  '0RNRSQ7hVOE',
#  'CklsOt6zbTA',
#  '9BwdJ2DmCz8',
#  '9odnOjqkQWs',
#  '-OUz30LSwMA',
#  'EfeD1GQOsWo',
#  'UoyUL-5Fbhw',
#  'Hz-sPrPH4P0',
#  'd0ZjWUsX9BI',
#  'IrJLOiMt1PQ',
#  'ye9MVWGN9X0',
#  'CNB195_60a8',
#  'mp20AQR5_co',
#  'q3RGDtn3HA8',
#  'qO17fWqtX0I',
#  'zy3_spl5ysw',
#  'vc-uC5heZ0A',
#  'uxfpBWkzp8U',
#  '0Pl7l3VFtfs',
#  '1Os75Byg7Js',
#  'ihXIhp4ZSmM',
#  '4OJkIIlWWqU',
#  'L-kByyBWIiQ',
#  'LiBRuZxlNcw',
#  'Pf_Ef9O5X20',
#  'zcKKpxwYckg',
#  'EvT-VlAlgw4',
#  'IbUbaYZ7dn4',
#  '2TybSQZt3MY',
#  'i1z5ahjYDII',
#  'A8_SQwZmfBQ',
#  'xLGEJ7Lt2gs',
#  'IzWPA4LigLA',
#  'FQC3dxzG6_4',
#  '0Nf1jFdu2vE',
#  'A1SL8nwwFRg',
#  'jEqRGfCik88',
#  'CykkP7V0GzA',
#  '6bULWFFtKMg',
#  '6_jCxChTnxQ',
#  'E65W3msL3RQ',
#  'YTgPp4iRrgs',
#  'q_6fCKMQO80',
#  'y17T2GLpSnY',
#  'EO0bYnH-gtA',
#  'NpPDpWzx0_4',
#  'FkGirZ_ySmY',
#  'DIbZIipwAG4',
#  'KlsZfUNw1-4',
#  'yiS-ShkYuSg',
#  '8KuNPelm5JE',
#  'X_-u0NYolyk',
#  'EEIjkKXxxp8',
#  'pJ70wzxMYFE',
#  'iykhWOfeYqo',
#  'guoYisCQahE',
#  '4jJu_1fpOA0',
#  'rzDb8eyeLhU',
#  'JrpEsIo6k3Y',
#  'iCqMWzll__8',
#  'd2CHs3TF2iQ',
#  'N6cgktKzRek',
#  'gIDlGpI1BT4',
#  'S2F4d5diLCA',
#  'Dhy2x96iQo0',
#  'c9GXecC6CJ4',
#  'QtN0o7w0_d4',
#  'KwYt2qtWM2E',
#  'pv7WAPOipRk',
#  's9HD2atybtE',
#  'mUI8Vg_e4bs',
#  'B3C-DdDkKYQ',
#  'exipPx5sJ2k',
#  '9s6ztQtntbo',
#  'iCOsldtxMyM',
#  'w3ornOvCX1c',
#  '3KvHGHZziI8',
#  'eYnRyO8cO1M',
#  'zKy4FsADgTw',
#  'HYTAL5nqD4g',
#  'JXE1NxBcRVo',
#  '44MbMP_kscg',
#  'kvAJjD7acKA',
#  'zbzorGog8lA',
#  'OYzi0CGVo9c',
#  'XAZCi2SYD2U',
#  'slscw6zbqX4',
#  'XwP2BkoQkPY',
#  'aIy-oytGMko',
#  'S7FdixSgsDA',
#  '-NqHUFCYo6g',
#  'bgetCpkEjI0',
#  '6xbgDX66FXU',
#  'EKyvGGeJaEo',
#  'w5bqap8Fe1Y',
#  '18BfvXbHH6Y',
#  'woGjZjZ92_o',
#  '2JCXiqRUR5Y',
#  'FtPUsWlmb6Y',
#  '6GtVI-yJmro',
#  'vUYD0Lx5fz0',
#  '4ALTSz_m-nw',
#  'Nt1wx5fVx24',
#  'JqP3lggoGeU',
#  'qCicalAf2as',
#  'xnlMTEkn-to',
#  'zw2TbzFWZJQ',
#  'siozsUYPT_A',
#  'CFNEJ9agDZg',
#  'lD9AeeUiy4o',
#  'J4wYfSqfMMQ',
#  '-bPcfLBAf34',
#  'dzFs5qTIEOY',
#  '1R0wv3KRsKA',
#  'tdvWuY-Mr60',
#  '8TM9gTIu464',
#  'BRkWjZtNfGg',
#  'AdQATyCfEx0',
#  'Ymg13x3tsEk',
#  'EsB5OqPJtHU',
#  'yF0s4ZvUpCU',
#  'DXifXUTTdE8',
#  'x-3mEVoF0nI',
#  'd_UYOUx4lZs',
#  'z-aul0hO4Us',
#  'EcemfC3xHWs',
#  'RkqAaPoRF7E',
#  '6s90-2fHN84',
#  'XW6tgprmqgg',
#  'oeLPH6tCn5A',
#  'Uw9yJ0Cs2PU',
#  'EWFoVhpl3-o',
#  'eB957_TYR28',
#  'Qn3qo-eHI7M',
#  '-_zpvVr1TAw',
#  'dA9UvLuuCpo',
#  'HvcmKUQ5CX8',
#  'jB0AocQeJE4',
#  '23byJQsIbJg',
#  'q-vfD-lxs_Y',
#  'xwcxu3PTk8U',
#  'zMMG0F85noo',
#  '8XqwdT-iVRM',
#  'dsllDW_nqWQ',
#  'e9wy9YTA3UI',
#  'wWQoIa7A7pk',
#  '4Lv1e5Hmogg',
#  'iDg41RMm40w',
#  'LlImHIIhkmw',
#  'BMgJdkiAlS4',
#  'glVX4QtPWo0',
#  'RyH1BfjkES0',
#  'KAifGn2vpn0',
#  'n6FRuKQvRlg',
#  'WW9WlsvyjJk',
#  'FwLFi-59P3Y',
#  '478cDmKP9Sw',
#  'Ziry_yUvU7s',
#  'IQ-hVdciTEM',
#  'Lm6rwSc8dHY',
#  'CpwgQyj6g7g',
#  'tRz7iJVEY8U',
#  'CPE_K0GPeR4',
#  'gtAb62_qI9I',
#  'N7qdxEZRkfk',
#  '5-BgiGPo_iY',
#  'lueobUmgHu0',
#  'zw0UQ3CcaRY',
#  'FYksCFiu09o',
#  '03UxMgx5THI',
#  'kEcPDOpybH0',
#  'nh11lXjo4FE',
#  'OI0N-Ec3HaM',
#  '4fvcYjJ4XdU',
#  'L7TmQLfaZiQ',
#  'gKN5choh6Ps',
#  'qA85IPM8p1k',
#  '9QxipzxHF_4',
#  'XdiehB77xts',
#  'DC1AZXJngII',
#  'JBQ-fhoFx4g',
#  '-v0KS8AxnK4',
#  'YO9-oc8NUVY',
#  'NGtOzwfNUjU',
#  '2yOa_D-YZfE',
#  'q4b6UotMCH0',
#  'TuP4puXTMFA',
#  'nFsLS0A6_-8',
#  'aZmX6c1qEmc',
#  'XAyIItk6qf8',
#  'LL_LK1a-PO8',
#  '2vGNyWet37s',
#  '4lEwf3Go3kE',
#  'MEIo_Izh28Q',
#  'svfHaaGLAdA',
#  'Bk2thbG6meE',
#  'S0VzjBQSxpA',
#  'rw8pP9wlsyM',
#  'CV9opthr-uA',
#  'T81ONsxyk3s',
#  'NYlZ4DeGDxM',
#  'STCcOJqQ7j4',
#  'NW3PHMYaAnU',
#  'TbOGShvIjrs',
#  'W8Ye4Jpr_Jk',
#  'gCLvOBS5Bdg',
#  'UE0fek_NKWk',
#  'EX09rWQBl5k',
#  '2MMbMo7-Teo',
#  'AxJWikOcIuA',
#  'V9PRVKREGg0',
#  'KJ8mEkg4B70',
#  '2b0Fjxf4FCU',
#  '9HfCE6O0fDU',
#  'Jqc3EvSc3G0',
#  'y-8JNqQte_I',
#  'GVRTgAiI-80',
#  'M6916-hVQhg',
#  '6t8RE9_YHuA',
#  'fKFlsitOGh0',
#  'ji71SmgOMBA',
#  '2ZkyuQG3Qbg',
#  '3wdlDYPtjaM',
#  'wRP3NWBMPM4',
#  'XMkb7GjT06U',
#  '6kx8m78XpIk',
#  '2gVUwJX3t2M',
#  '6TArUnduok8',
#  'qC2w9aXdcKc',
#  'j83WL5KtoNU',
#  'SYBe7SkJlzE',
#  'ruJWaotoxhs',
#  'W_-frbhB1pM',
#  'Ezk4o_TRajM',
#  'SmXnJBnI6P0',
#  'V00lI4wAnNY',
#  'H2xB8HZd0Xg',
#  'nMwHaA_Gc98',
#  'Aar-aovRlec',
#  'm7oH7jCSszI',
#  'EhmhTlceLN8',
#  'Z-WkdAo08Oc',
#  'atqEfs2vz2A',
#  'HlA42CSPC5k',
#  'KHpK5O5euS0',
#  'iwAqi9Tg1xA',
#  'cYxtbMVws5I',
#  'funrR30TUvI',
#  'rvUa2FUIpZY',
#  'SVbbnO2_b3U',
#  'qlrRZr0Dq9Q',
#  '-gizig5wKoQ',
#  'PW3QPee8a44',
#  'ou7gXFe_UrM',
#  '6rm753jgwzQ',
#  'VsLfpmZEtq8',
#  'HrpYsmIpKMc',
#  '-3VH68JyW8k',
#  '1q1FR3ZZ2Pc',
#  'BHbJrs7Mj0A',
#  'c3uvHcNgo_c',
#  'f15DFty1ZBg',
#  'Stsvia2djCs',
#  'OCLxhLfQcKA',
#  'VcRJFCwT8Fc',
#  'mvIA2E7MA30',
#  'EbWnjTWPifQ',
#  'SYl93dQ8USY',
#  'WZLQaAGQ-Y4',
#  'zz8yuSNWInA',
#  '39uxKhe079M',
#  'ZBlPROkBBFc',
#  'JMI5vSztYC0',
#  'g59ZPdi_u9I',
#  'yXzfsRBoRD8',
#  'xT2jIwapkxI',
#  'VctknQV1qcs',
#  'w2rBG5zH5Ko',
#  'iUBrpD3b_bI',
#  'Jx3S7VMgvXs',
#  'RJ2x8TTyldQ',
#  'Xjsn-7lERNc',
#  'sQW0AMvjZgY',
#  'Yj4x4g0Py5o',
#  'de0mf6mKbYc',
#  'qPCeBpISx-8',
#  'dTz0TQVC_L8',
#  'FEE024XkeGA',
#  'kH-XIQwh0qY',
#  'lY2uQw6XOPI',
#  'SoN8_xrsjlE',
#  '-R7iHNq8yhk',
#  '9dqIX6Q6Ccs',
#  'j8UceJ4uDxs',
#  'ccvOCWALZFA',
#  '8iDmYABIGR0',
#  'W9NjLyZBgL0',
#  'OnR9XH0UU8c',
#  'Kn9Ad4PV8GI',
#  'Z2S_8VjFudg',
#  'Kxi_JTo_Uqs',
#  'Y1OLJVGUyxs',
#  'ZDg5u4Zw27E',
#  'oKQBjeQQ9FU',
#  'xA-bIcCeams',
#  'qd2JBkuoPKg',
#  'nNe-5bPG0jA',
#  'tN0k8MJe0BA',
#  'y1AW83l7J5Q',
#  'Oig0hzOFieY',
#  'sCcAcm-sZcM',
#  '9J1bFOhSsuk',
#  'sltP9pcsMek',
#  'hAnJ8B6dZlE',
#  'ZSuWPsEtznw',
#  'bAz3qN3Lz40',
#  'xCZN5ksGaIU',
#  'u9o1EMBEKdc',
#  'gmT1oaysXuY',
#  'PDEeEMNn_Xw',
#  'xh44VKkD8U0',
#  'Ey49T93GFVA',
#  'lb_036812xQ',
#  'vlkTaIItar0',
#  'OHDdoIqrfIQ',
#  'buyw-0scTyo',
#  'TzMtivbIN_o',
#  'sLFMulUBMt4',
#  'Lv8p7HM9_98',
#  'eMdky3sG8Bw',
#  'zrAN3XcrhIE',
#  'a1HXNuaTpEE',
#  '7lK-8bnIQmk',
#  'd1lH3VSt-u4',
#  'KuJF8-fsc00',
#  'R2MqAwRsnVk',
#  'MJIlqVOT-Tk',
#  '-QsWx3fIM8U',
#  'O7FDR9k13g4',
#  'AuGo56nh9HU',
#  'jL7cVEC3wAI',
#  '4Mr9XJR8dOM',
#  'CllhN1sgLpQ',
#  'T-GsdVTUpbw',
#  'swHY6Y_8C7g',
#  'yYvDBIQryVQ',
#  '9kDQOZblA1g',
#  'FRhUNUEXzSs',
#  'F8iB6sENhHw',
#  'ceVvTAQ_2To',
#  'kfuxHfl1Km8',
#  'j9V6AKNOTGU',
#  'ggzG9_3AeDU',
#  'sfgEnmRAIec',
#  'oTeoocEThGE',
#  '0bcgLo-kYQs',
#  'i6kLRXbCfOE',
#  '51iuo_AKORQ',
#  'r5P1AtGifl4',
#  'pNoMDcYFpFw',
#  'E8UCX7ElijY',
#  'YIiSyAzhJWE',
#  'qotY96gjOE4',
#  'uk1v7iFnDmo',
#  'blpNi6H4VFs',
#  '82XnpJ_zlf8',
#  'eFcFqHSI9Oc',
#  'ZJApozti8bI',
#  'CanqtRoktOc',
#  '9GPWTwNZN68',
#  'FiHJaPVcUGA',
#  'tyiaYjZotxw',
#  'Wm2P6hdADOU',
#  'vw3bcBZRSWA',
#  '05iNY94aJ_Q',
#  'd6uV06N60JY',
#  'j5rSxrLS8xA',
#  'BAgPPVOpes8',
#  'Z9IdvezlchU',
#  'As39WmRSCME',
#  'zSljpaSG0Ls',
#  'xfS_HuW3o60',
#  'JxzNCcztBjI',
#  '5bJPZ5gahkg',
#  'kCOmbwiWdZA',
#  'JT0GFWedwHg',
#  'WPTng4KAWaQ',
#  '2J_YXMY4juU',
#  'hfDH9sMEykk',
#  'DuwUO0u_R5o',
#  'd6gY-IsKLhw',
#  'lyarRYC2FxM',
#  'Id9biYzG7fk',
#  'WMLM9lTGvqs',
#  'C-fgHgzIriw',
#  'pyDbKZadDDg',
#  'MMjVoYHK8NY',
#  '4D-GiVIcM7g',
#  '0UQAdAP2xS4',
#  'bUUQdymkNAI',
#  'E0RsvRcOeKk',
#  'RjZLHulODs0',
#  'EGcIKQ9B1Ww',
#  'IHld1bXbs0k',
#  '7Cxellr6urc',
#  'w1Yz_XqgQAw',
#  'tT8dV3i4kF8',
#  'RZcdBqyUyYk',
#  'ZYuEWGkJbtk',
#  'cJ2gdDBjV1E',
#  'vWLWkXsCcJo',
#  'gnUft0k-rys',
#  'a_N9I53zL5k',
#  'nBmPNYnLYpY',
#  'fMskusEfjG4',
#  '43m3TC0pKaU',
#  'HzuURvxHdcE',
#  'TezHkQBPo1c',
#  'xTXD9uhEkLI',
#  'LcG_q3H0cbU',
#  'Qd2-q6Ypkts',
#  'dc9K80MMOUY',
#  'tm-t5Jtyxhw',
#  'CKy4xEEwGrc',
#  'xLWGhT4-qJs',
#  'yVD0U7aJxtk',
#  'f6-Y7z28O0Y',
#  '81iYg1jdlnw',
#  'f4-Vir3BFEc',
#  '5EGR-Z4u6k4',
#  'n7VA2p-0brw',
#  'i-zJ6P6u57A',
#  'Uw4-l4Arp6s',
#  'weBf-5JPgMk',
#  'PAEfN3f2iDc',
#  'MieZwLAXvqY',
#  'ukb3IGBM-Vw',
#  '4MDn0fFf0go',
#  'lPPPnGljGEA',
#  'E4HBC-YL7hc',
#  'TfhoWrSfxFM',
#  'nqxvsmzgeKg',
#  'cH_DpVP_zHM',
#  '-ymof8K-Tbk',
#  'MFvKNEzLMyU',
#  'hK-GE3HiIpg',
#  'hYyyFqHlX50',
#  'UNYZh0Athk8',
#  'PV0rjer6r3s',
#  'oKL9-Ilv2kM',
#  'GM9hXqcsjjE',
#  'Fs5sdmOEfV4',
#  'AbVpbVuLc0E',
#  'XkZYfNhFCMY',
#  'cwKqF2grKa4',
#  'KGWLaIucFcM',
#  '9otLUNLbXB4',
#  'l1vdq8kcq5Y',
#  'aJMQMBwa8Pc',
#  '1FMow90nMCQ',
#  'Ry91HU2fz24',
#  'wmAqadplVmY',
#  'rZpSRhzjegk',
#  'gmmUq8Dholo',
#  'c6_ESbwfHDU',
#  'J9GdXNug6Qk',
#  '9tQQJHa7qjw',
#  '1Y4Fq-fnX2U',
#  'W5CFw1RhSHs',
#  'M890q3OU6Oc',
#  'wjBJHjteA8I',
#  'zhYBa1mL34k',
#  'NDRr_TE3hFc',
#  '8xa3YbGHMvw',
#  '80OFF_PEFI0',
#  'I92DZQfAAOI',
#  'IwmuQPYahrQ',
#  'qqMla2RostQ',
#  'TPJ6kdb_07o',
#  '4dzpI5mglSM',
#  '-jTsbYud8FU',
#  'rL50ch39O-s',
#  'IzvtBe4a8SM',
#  'i2TwlCMtevI',
#  'xpptovF4Ee8',
#  'INMGzsIcBFQ',
#  'SYYw6JDFI9o',
#  'D6qUlrOKWyU',
#  'lfQSGIeJ_E0',
#  '5L2j5zknSjY',
#  'pxTYqEEJ0hI',
#  'YHyj-XMLtRw',
#  'IcdQp2Jk34E',
#  'jBul8kIQdNY',
#  'VrJMeTlxcNk',
#  'kpkIMrjjevo',
#  'qZuPwav_DFQ',
#  '8pVdQzmdkG4',
#  '7xlKmIl5yVY',
#  'qislbvCclas',
#  '1mZyRxz2KoA',
#  'MvMy-Hbu8yM',
#  'CLUvlswInls',
#  '74zPKGOsHVo',
#  'aWqJBwiHExM',
#  'YTK8k179nvc',
#  'ySPLzpFRT8I',
#  'vEac-UyvOTE',
#  'MretQ_zud8Q',
#  '2Zi5PgrdtWw',
#  'l_QsBMT7ABk',
#  'QnGwF0EkEgo',
#  'U8wxLltu_z4',
#  'bWOoa5UwRAI',
#  '8ddDKYOmRNE',
#  '_djbDeb89fI',
#  'KvbpHjZ--O4',
#  'cWIn-aS30AY',
#  'aOJiOFgteag',
#  '5jGCCvZuGQ4',
#  'oZ92OFQQKC8',
#  'lEUM_5xiAmg',
#  'DLww14zJZnI',
#  'Q2zniGAZX-A',
#  'yyfcZh0EnQc',
#  'fKxsiNtgjsM',
#  'zsNVcplZ6a0',
#  '4WUL5AbVwG8',
#  'OdB-LhRVlFU',
#  'zjRomE8KshE',
#  'G8sY9e2Vfjc',
#  'xUQ_fPlamdw',
#  'yhsKgPKpJKM',
#  'EEVuDe8YHgg',
#  'DOqMZ4BS2ac',
#  'pDLpo8ZbWg0',
#  '_Srha3-S_xk',
#  'dmFX1CfbvCQ',
#  '2ErSnJZbYWY',
#  'PrFD-Bf5xhs',
#  'y7_rQdjFeGI',
#  'oHZqhFpNU-A',
#  'T2b3E6XuznU',
#  'xCEZjGjbOqw',
#  '0aExjDw3kGw',
#  'bwxA32gwm_k',
#  'bReCuAgK5IA',
#  'hq5e1loj4fs',
#  'rsDvdSOFgJ4',
#  'Zv-Cc5Po8jg',
#  'PB96E0Wm98o',
#  'zwZG16s8aVI',
#  '09Ue4Jd83bs',
#  'VLhjdvS4GIc',
#  '6jcwlkoPSrg',
#  'ZQx-Jsdb0l4',
#  'zaVGo2wzGHQ',
#  'Nt55LUtD7WA',
#  'oMlWDeZfj60',
#  'nOa7_vavXDc',
#  'i4D9WI8NGYo',
#  '6YgisNi28EQ',
#  'IDwREeyXBSk',
#  '9lyBJtnUY9c',
#  '9GZoy4MJFeE',
#  'GH-prKoc8ek',
#  'qjmixSi2BHM',
#  '6AvDdUPzwok',
#  'R7cTIAkvz4E',
#  '4B7DfSChAZs',
#  'ty8aeLkWm9c',
#  'dGdeeo0mmAE',
#  '3U07dxmPktY',
#  'yyBbDcIhWoI',
#  '1EWnBKooXqE',
#  '0OUAxhdzYZ0',
#  'toxSA6pbu6s',
#  'Hll2D8QTS2s',
#  'k_DV6ldd7kw',
#  'ZPRy5komGus',
#  'UBPBLpFODys',
#  'eDt92SRXulA',
#  'oPUzVXufUVo',
#  'TbjLk6KjdJY',
#  'XlcixLlDmTo',
#  'eo2eO6pLqtg',
#  'a7b1hfURQcw',
#  '12kjc5Te64E',
#  'MDdR01T28nQ',
#  'h6ksovKJ4Wc',
#  'ewTlod0BwzQ',
#  'DS0NE0qWw7k',
#  'TT8bx-CgVVE',
#  'iMceBh6sYoA',
#  'cv_AMj62Z6Q',
#  'UvVTFCin0NM',
#  'howiRR-AMTg',
#  'mmwDT2H2s2M',
#  'pDFoQAPfz2Y',
#  'sYR8OC0Tlfo',
#  '16nyD3QwFDo',
#  'O-sYWytrNBI',
#  'v9z7HmCsxOg',
#  '9TiotgvgjvE',
#  '9NcflH3dnMo',
#  '3dujqJzZQDA',
#  'dgaN3a6G-b0',
#  'Rj2tpEFIqcs',
#  'E4PF4QvInVo',
#  'fD9RHjYxctY',
#  '-AfjHVQIBAk',
#  'Vy3SjGyo3-g',
#  'v7UJOptvR68',
#  's-FoTYzpWbk',
#  'j1DQmMj_mnY',
#  '4Gz79gmZlS8',
#  'HFqIE9n98B0',
#  'eZje0k5sTkM',
#  '2OAPJe9KFCs',
#  'NM_USD-5FVc',
#  'GTCYswgvLdA',
#  'l605jdY4aQY',
#  'RY6HN-YK8mo',
#  'pAIH9BKrb2E',
#  'hTbKdLVtuDI',
#  'KMxoub1rEmQ',
#  '5hE2946GKsA',
#  '538rZUbsYu8',
#  '5erZ9CWmmRs',
#  'BihTEzqc5oI',
#  'qC1ZTLV_N5k',
#  'oe_rShZCcYQ',
#  'GCc9BV1I5F4',
#  'AwKcuzSLUR4',
#  'Nja8QJo5asA',
#  'Hdz6Z8la6v4',
#  'NzIMM6Vv1iE',
#  'crDkVJuX3-o',
#  'lyhmn7-ykzY',
#  'VV0cj9OOMsE',
#  '59EWg8JkQT4',
#  '63O4k9js_FU',
#  'KAlFp6rZejU',
#  'SdHAQPYkEtc',
#  'qIapyEvUD-8',
#  '4p88adUygqI',
#  'lE0Bpc4pJiI',
#  'WACHZ165Lng',
#  'uTT7H_S_HME',
#  'mW6IjeQWvd0',
#  'Ptob5AsS7yM',
#  'eDMf1gQTmys',
#  'K3-Od4zNAIo',
#  'Ga5FrXbXX0s',
#  'vREERm0PRlk',
#  'lx5a2UyzWdc',
#  'jE1J8tAH2dY',
#  'EyBXiwRvrgw',
#  'xWyP4gJm6_Y',
#  'oCb6OokqQ-4',
#  'ckIu-MltC_Q',
#  'Rq80jOA9R8g',
#  'PuiTyOLzFLE',
#  'eo9ZVKyn91w',
#  'DA8XzSBUa1c',
#  '0zEZP4trqsQ',
#  'uDm39C9usx4',
#  'ZhDW2BLYVU4',
#  'VioUVzjDdVU',
#  'yRqLL3sgvxc',
#  'ssLdyz2moGI',
#  '97OIKYo8Dqo',
#  'jU5-T-9uL-U',
#  'Yp9AgpRg6zg',
#  'TZsl9lyLH_c',
#  'gLuSdkh7D6U',
#  'dccgcVltANw',
#  '8eLM4a_9_Vk',
#  'dlFHbNM3WuY',
#  'Z6-jN8c4KeQ',
#  '758P3ycaxWs',
#  'XLHX4QbocfA',
#  '5Fzs8CldW3k',
#  'GjvP5f4DujY',
#  'ysblSW9q1lg',
#  'g_nbtgMW7_4',
#  'C_i3atLNCVI',
#  'fgB7BUlBXo0',
#  'j88As80JRwM',
#  'lYhO35HcviY',
#  'v78BZOQ6tBE',
#  '8jWPDwf56Ds',
#  'lzCw_vV2d80',
#  'hFUXRRuoI68',
#  'zUKwu-0shiw',
#  'j51V1UoHM9U',
#  '42CLsm9p-C8',
#  'pWtziOR-6Ys',
#  '4rGnHWhSXVY',
#  '4-zExWBLNhw',
#  'UidS9-uryEs',
#  'k2IlosotGrA',
#  '2H7AyLASCMk',
#  'ciPqXCkTAhw',
#  '2CE9SnMylr8',
#  '-XG4bYM8j4o',
#  'kZuI6jz_h8g',
#  'IY6Ccf5Dnz8',
#  'pAAkOqnzEx4',
#  'eUIld7cOr9c',
#  't59ZVPV7nXQ',
#  'sY6oZQrfB-o',
#  'O-pWu7PfkI8',
#  'I6au9tLLIw0',
#  '1TS-VbN1zLQ',
#  'kfsDs-o_ae4',
#  'WGTZAX3IUTU',
#  'ZG4zw8hslRk',
#  't-3LTkIOihs',
#  'kICyJobWKLU',
#  '_ijQDfC3y8A',
#  'QxwWsM4U8aw',
#  'M_f2rVSu3f4',
#  'uxixAuLOnM0',
#  'piRQjtZoJ-I',
#  'uVrj2Hy3_WA',
#  '8_lY0Huj7zw',
#  'i3L7OKI05wE',
#  '26-GJyDCfuw',
#  'DMet_IZPlVg',
#  'cYdmj8FkQD4',
#  'aqgcTxMGKOg',
#  'aIZcmLPb8YI',
#  'qdz-nvTXjWU',
#  'zsnLJS4xJYI',
#  'jj3cwVwSWjE',
#  'tRXEG4RwyOk',
#  'xCchbqSmc-U',
#  'KUYxKPehbhI',
#  'c24iSMbvsKY',
#  'r35tTCOQqIQ',
#  'tHKCB7Rg_HE',
#  '8XRo3hfgR0U',
#  'ndKQaY_RpWk',
#  '91ijVC24XNA',
#  'L1ljOORLUEk',
#  'tpGaFwjJP30',
#  'T5X45TEZjHY',
#  '8aewDMbA-bI',
#  'H-DYPCBq2AY',
#  'bgdcDWndqTc',
#  'XRbVPKJLJJg',
#  'Sz2y_FgUyjw',
#  'ic6_JOikt34',
#  'iN6RKyk8I3s',
#  'qavpbZHvSHA',
#  'oyJ0j9CIqZ8',
#  'sARvskeE_hQ',
#  'B80b2MlOcAM',
#  'ciaKkXWa2Q0',
#  'mp4jMvon5Og',
#  'mezaPNlxo6A',
#  'WsocyYr3wLg',
#  'u3r8iQipGFU',
#  'wINlLsk0T34',
#  'kU83_PQIAWU',
#  'IFrgDxbTQDg',
#  'T78PkC9sGGU',
#  'Jbl6m9LnbtY',
#  'L5ZB1hmE1MU',
#  'LH1O0tiMhgk',
#  'Se2G-ICbafY',
#  'pcoxlrPC4JQ',
#  'Dnqx8hNL5HE',
#  'thHkPeDYFVE',
#  'tTMRoQzcEUg',
#  'FoKjCrwk-xc',
#  'P9ENBNtQZ58',
#  '2hKPpJVcWkE',
#  'M4CFHdBJ54Y',
#  'l_xrXvjeL_Q',
#  'UDiGKORO3zk',
#  'j_0caPSy0s4',
#  'H0byDIeFAVc',
#  'cwM8INy1-W8',
#  '6BkNeDoqbkY',
#  'QlNT6SXsfMg',
#  'zTjMbcf2x38',
#  'pk1N0OveSwU',
#  'IjhCsw_RMgk',
#  'PACYk5r5ZqA',
#  'IyPJB2wv950',
#  'z2HMtRjDNHc',
#  '-4LJpwZFc7E',
#  'ia7pGg7k7ZE',
#  'OgKnbQeR3-Q',
#  '6kzwDUTqAAI',
#  'xqSQusK6IAU',
#  'H3gg-wXcWkk',
#  'TMPq-deuvVA',
#  'DS5IUTiEFC8',
#  '1bK7kPZhrmc',
#  'd9Eg-Hvjpcg',
#  'FNVVSJ0XH98',
#  'TPzb3xAx21I',
#  'K29mQ4PzN4I',
#  'homX9MPO8Ms',
#  'uiN29Q3_gxo',
#  'eb2m5U1sPYY',
#  'jItbxNPpKmA',
#  '2T704Zz2O9U',
#  'n2gZhjAVy78',
#  '2bLA863FO4A',
#  '5bRW5VLg330',
#  '-Q-ZpoATlpI',
#  'usX5AiAJnlY',
#  'mhZ0JS2qbVI',
#  '0JF01IHqM_g',
#  'cc3OcYNIBXs',
#  'UAwkEVBhqvo',
#  '1e3064ISoiE',
#  'tDXQq5XXzmM',
#  '0YOOWmHTTzQ',
#  'J-M6AV307tk',
#  '7cVvExOSX2k',
#  '1paTgKzdfj0',
#  'Y2nFOg0LQE8',
#  'PByU2A6OMZM',
#  'uXedzKeg7RI',
#  'UiudAGd9UaQ',
#  'TKDAlVhOSdY',
#  'a_-Sr_dc824',
#  'hsoqT-zO_vQ',
#  'YIKLvONv3zE',
#  'FpZ59sSB6G4',
#  'znO8pFFQqQk',
#  'lFFJyXh4Pak',
#  'x3Hh_IPZvsM',
#  'MSIxHw975A8',
#  'qKtMhHnUFic',
#  '1_NxZykEdDM',
#  'TGtGuKsT_cI',
#  'OBawqfPdVtw',
#  '_zqJn8DhcmM',
#  'L5AZ0du9KDU',
#  'AuWLs0AYdR0',
#  'QhD4rkoojdM',
#  'QJaTEdmIZK8',
#  'eSFeGg-_Cpc',
#  'svaMkWbbfi4',
#  'JKFlorJCeOk',
#  'ydp1Lh4EhZM',
#  'mXf0Dft_4wE',
#  'k-fKfEUgmeM',
#  'zy_YQ0nDscw',
#  '85GuwkIVy_s',
#  'fhgfE0YnH70',
#  'TIoOkYKl28Y',
#  'mzbG41ogHWg',
#  'nEUEZTqATKM',
#  'GzcgS60Ho1Y',
#  'w3Imww6Bmfc',
#  '_RGJWmNBR8o',
#  'H-R5WAQX5o0',
#  'kzZ9CdVNJws',
#  'baSmWL0gft0',
#  '1MzBgxM5cQU',
#  'vpOD3DWF-cY',
#  'av7rwFKX8-A',
#  '-ydVohwXWSo',
#  'tm2Mh9vbyHs',
#  'LdSkR-0cc_w',
#  'jdJv-liMsWU',
#  'fCMDSBhk_8k',
#  'yYZZ6AtjGMk',
#  '3-WaiFQ2oNU',
#  'wlp_o7UJtGo',
#  'OtueXBYgiTc',
#  'YLCfMR-ShyM',
#  '8X8s2tlemvw',
#  'DgNZQPDwXow',
#  '5jwWoYY3tXU',
#  'mQ79wQJup7w',
#  'ZE97D3ztjvw',
#  'UTDeluPuQAg',
#  'cvMmFsy9CrM',
#  '9uuiGl1-Yfc',
#  'gCYJQYvaf28',
#  '7fH69__jkV0',
#  'ePpbNqj1pVY',
#  'j5Q2xFv3nuI',
#  'PvSYlEMpn7I',
#  'cJzri5QSfLs',
#  'Te-XnVU3fOc',
#  'AYhNs7mntLc',
#  'xrXN1eQP_Lg',
#  'ni0edkxK6ds',
#  'cwd98mOMLfg',
#  'YynKe6QEUIE',
#  'ZYL1V7-JGHI',
#  'HcZma-8DQwg',
#  ...]

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        
        response = request.execute()
        
        
        for video in response['items']:
          try:
            Comments = video['statistics']['commentCount']
          except:
            Comments = video.get('commentCount', 0)
          video_stats = dict(Title = video['snippet']['title'],
                             Published_date = video['snippet']['publishedAt'],
                             Views = video['statistics']['viewCount'],
                             Likes = video['statistics']['likeCount'],
                             Comments= Comments
                             
                             )
                               
           
            
             
          all_video_stats.append(video_stats)
            

    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_details
# Out:
# [{'Comments': '11',
#   'Likes': '36',
#   'Published_date': '2022-08-12T05:00:19Z',
#   'Title': 'Perché Ryanair non venderà più biglietti scontatissimi: “Dite addio ai voli a 10 euro”',
#   'Views': '2140'},
#  {'Comments': '87',
#   'Likes': '134',
#   'Published_date': '2022-08-11T20:25:26Z',
#   'Title': 'Intrappolato 8 ore in un tunnel sottoterra: folla applaude quando i pompieri lo estraggono vivo',
#   'Views': '10497'},
#  {'Comments': '11',
#   'Likes': '107',
#   'Published_date': '2022-08-11T19:30:03Z',
#   'Title': '5 modi per combattere ansia e stress #shorts',
#   'Views': '1734'},
#  {'Comments': '357',
#   'Likes': '587',
#   'Published_date': '2022-08-11T18:00:30Z',
#   'Title': 'LucyLein a Fanpage: "Senza fare porno, guadagno 50.000 euro netti al mese su OnlyFans"',
#   'Views': '17188'},
#  {'Comments': '50',
#   'Likes': '171',
#   'Published_date': '2022-08-11T17:00:29Z',
#   'Title': 'Maria De Filippi: “Non so se avrò la forza di tenere la mano a Costanzo quando morirà”',
#   'Views': '21185'},
#  {'Comments': '31',
#   'Likes': '77',
#   'Published_date': '2022-08-11T16:00:10Z',
#   'Title': 'Il fidanzato di Donatella, suicida in carcere: “Abbandonata da tutti, cos’è successo quella notte?”',
#   'Views': '5824'},
#  {'Comments': '85',
#   'Likes': '219',
#   'Published_date': '2022-08-11T15:12:53Z',
#   'Title': "Le immagini dall'alto delle risaie colpite dalla siccità: così i produttori rischiano di fallire",
#   'Views': '8393'},
#  {'Comments': '21',
#   'Likes': '139',
#   'Published_date': '2022-08-11T14:34:53Z',
#   'Title': 'Mario Paciolla, la mamma racconta gli ultimi giorni: "Abbiamo denunciato due funzionari dell\'ONU"',
#   'Views': '5962'},
#  {'Comments': '237',
#   'Likes': '334',
#   'Published_date': '2022-08-11T11:31:08Z',
#   'Title': 'Le parole del papà di Alessia e Giulia, le sorelle investite da un treno a Riccione',
#   'Views': '24157'},
#  {'Comments': '17',
#   'Likes': '368',
#   'Published_date': '2022-08-10T19:00:04Z',
#   'Title': 'Ghiaccia-testa cos’è e come fermarlo #shorts',
#   'Views': '8967'},
#  {'Comments': '99',
#   'Likes': '607',
#   'Published_date': '2022-08-10T18:00:14Z',
#   'Title': 'Lascia il calcio a 23 anni per salvare la vita alla madre: le ha donato il 70% del suo fegato',
#   'Views': '35285'},
#  {'Comments': '44',
#   'Likes': '106',
#   'Published_date': '2022-08-10T16:10:36Z',
#   'Title': 'La prima estate di Francesco Totti da genitore separato, ma Noemi Bocchi è vicina',
#   'Views': '44192'},
#  {'Comments': '29',
#   'Likes': '256',
#   'Published_date': '2022-08-10T15:00:26Z',
#   'Title': 'Come evitare domande scomode in famiglia',
#   'Views': '4559'},
#  {'Comments': '452',
#   'Likes': '420',
#   'Published_date': '2022-08-10T13:03:11Z',
#   'Title': 'Spia la moglie col gps e la trova con l’amante: marito lo accoltella 9 volte, 40enne in fin di vita',
#   'Views': '26442'},
#  {'Comments': '28',
#   'Likes': '319',
#   'Published_date': '2022-08-10T12:05:07Z',
#   'Title': 'Michele Molteni, lo youtuber del fai di te, è stato operato al cuore',
#   'Views': '10251'},
#  {'Comments': '32',
#   'Likes': '250',
#   'Published_date': '2022-08-09T22:00:15Z',
#   'Title': 'Perché di notte siamo più rischiosi? #shorts',
#   'Views': '7997'},
#  {'Comments': '62',
#   'Likes': '136',
#   'Published_date': '2022-08-09T20:52:09Z',
#   'Title': 'Maltempo in Campania, in provincia di Avellino fiumi di fango e auto travolte: "Domani sarà peggio"',
#   'Views': '16710'},
#  {'Comments': '661',
#   'Likes': '824',
#   'Published_date': '2022-08-09T17:27:17Z',
#   'Title': 'Violentata in una cabina telefonica: 30 persone guardano, commentano e non intervengono',
#   'Views': '56543'},
#  {'Comments': '206',
#   'Likes': '319',
#   'Published_date': '2022-08-09T15:05:39Z',
#   'Title': 'Bambino di 12 anni travolto e ucciso da un pirata della strada a Milano',
#   'Views': '15047'},
#  {'Comments': '29',
#   'Likes': '124',
#   'Published_date': '2022-08-09T13:23:47Z',
#   'Title': 'Chirurgica estetica all\'estero, attenzione ai pacchetti \'tutto compreso\': "Costi bassi, alti rischi"',
#   'Views': '5152'},
#  {'Comments': '42',
#   'Likes': '156',
#   'Published_date': '2022-08-09T10:42:35Z',
#   'Title': 'Berardi è una furia, cerca vendetta dopo la provocazione di un tifoso: lo trattengono a stento',
#   'Views': '14977'},
#  {'Comments': '214',
#   'Likes': '1126',
#   'Published_date': '2022-08-08T21:55:00Z',
#   'Title': 'È morta Olivia Newton-John, l’attrice di Grease aveva 73 anni',
#   'Views': '88695'},
#  {'Comments': '8',
#   'Likes': '215',
#   'Published_date': '2022-08-08T20:00:10Z',
#   'Title': 'Cosa sono le stelle cadenti? #shorts',
#   'Views': '6941'},
#  {'Comments': '48',
#   'Likes': '133',
#   'Published_date': '2022-08-08T17:37:34Z',
#   'Title': 'Pagati per dormire in pigiama: azienda cerca “dormiglioni di professione”',
#   'Views': '8985'},
#  {'Comments': '106',
#   'Likes': '117',
#   'Published_date': '2022-08-08T17:00:09Z',
#   'Title': "Anziano beccato a bruciare sterpaglie nell'Insugherata: rischia il linciaggio",
#   'Views': '8870'},
#  {'Comments': '126',
#   'Likes': '402',
#   'Published_date': '2022-08-08T16:00:24Z',
#   'Title': 'Sparisce nel nulla dopo bagno con gli amici, Mattia trovato vivo 9 ore dopo aggrappato agli scogli',
#   'Views': '43373'},
#  {'Comments': '125',
#   'Likes': '369',
#   'Published_date': '2022-08-08T14:23:36Z',
#   'Title': 'Chi ha denunciato il sistema dell\'europarlamentare di Fratelli d\'Italia: "A Terracina clima mafioso"',
#   'Views': '22371'},
#  {'Comments': '185',
#   'Likes': '669',
#   'Published_date': '2022-08-08T13:00:33Z',
#   'Title': 'Il campione del mondo di jiu-jitsu Leandro Lo ucciso con un colpo di pistola durante una lite',
#   'Views': '65639'},
#  {'Comments': '478',
#   'Likes': '894',
#   'Published_date': '2022-08-08T11:33:48Z',
#   'Title': 'Il dramma di Donatella, la 27enne suicida in carcere con un fornelletto: “Perdonami amore mio"”',
#   'Views': '91587'},
#  {'Comments': '87',
#   'Likes': '464',
#   'Published_date': '2022-08-06T19:00:13Z',
#   'Title': 'Perché togliere la data di scadenza dal cibo è giusto? #shorts',
#   'Views': '17967'},
#  {'Comments': '142',
#   'Likes': '1199',
#   'Published_date': '2022-08-06T17:00:16Z',
#   'Title': 'Malato di Sma diventa influencer su Instagram: "Bisogna accettarsi per farsi accettare degli altri"',
#   'Views': '38613'},
#  {'Comments': '93',
#   'Likes': '914',
#   'Published_date': '2022-08-06T12:00:22Z',
#   'Title': 'Abbiamo sganciato una bomba atomica su Milano: la stessa di Hiroshima #shorts',
#   'Views': '35822'},
#  {'Comments': '355',
#   'Likes': '1316',
#   'Published_date': '2022-08-05T22:00:14Z',
#   'Title': 'Può esserci una nuova Hiroshima? Cosa succede se esplode una bomba nucleare',
#   'Views': '66214'},
#  {'Comments': '256',
#   'Likes': '976',
#   'Published_date': '2022-08-05T19:00:26Z',
#   'Title': 'Riappare la prova che inchioda i fratelli Bianchi : “Li avete voi gli anelli?”',
#   'Views': '137679'},
#  {'Comments': '115',
#   'Likes': '604',
#   'Published_date': '2022-08-05T18:21:52Z',
#   'Title': 'Dal carcere a 41Bus, Bruno che aiuta i familiari dei detenuti: "Trasformato un fallimento in vittori',
#   'Views': '48520'},
#  {'Comments': '273',
#   'Likes': '1473',
#   'Published_date': '2022-08-05T18:00:21Z',
#   'Title': 'Una misteriosa sfera di metallo è caduta dal cielo in Messico: esperti escludono i detriti spaziali',
#   'Views': '73181'},
#  {'Comments': '42',
#   'Likes': '321',
#   'Published_date': '2022-08-05T17:00:12Z',
#   'Title': "Oroscopo 2022, le previsioni e i segni fortunati dall'8 al 14 agosto",
#   'Views': '39837'},
#  {'Comments': '99',
#   'Likes': '116',
#   'Published_date': '2022-08-05T15:27:29Z',
#   'Title': 'Guidonia: viaggio nella terza città del Lazio che non vuole trattare i rifiuti di Roma',
#   'Views': '13063'},
#  {'Comments': '828',
#   'Likes': '3551',
#   'Published_date': '2022-08-05T12:49:04Z',
#   'Title': 'I funerali di Giulia e Alessia morte a Riccione, il messaggio dei genitori: "Grazie per la dolcezza"',
#   'Views': '389166'},
#  {'Comments': '173',
#   'Likes': '361',
#   'Published_date': '2022-08-05T11:20:02Z',
#   'Title': 'Esclude la campionessa dagli Europei di atletica e lei si vendica pubblicando la chat di WhatsApp',
#   'Views': '51837'},
#  {'Comments': '201',
#   'Likes': '230',
#   'Published_date': '2022-08-05T10:19:11Z',
#   'Title': 'Scarcerato “per errore” il 15enne che ha accoltellato Marta Novello: Cartabia invia ispettori',
#   'Views': '20694'},
#  {'Comments': '52',
#   'Likes': '71',
#   'Published_date': '2022-08-05T09:04:59Z',
#   'Title': 'Elezioni 2022, Bonetti: "IV nel campo riformista, Calenda si è sfilato per qualche poltrona"',
#   'Views': '3129'},
#  {'Comments': '35',
#   'Likes': '49',
#   'Published_date': '2022-08-05T08:03:28Z',
#   'Title': 'Aggressione Soverato, l\'avvocato di Beauty: "Quattro ore in caserma per ricostruire l\'accaduto"',
#   'Views': '3540'},
#  {'Comments': '63',
#   'Likes': '142',
#   'Published_date': '2022-08-04T19:00:31Z',
#   'Title': 'Le tolgono il figlio che diventa ipovedente in comunità: “Non ha avuto le cure necessarie”',
#   'Views': '11086'},
#  {'Comments': '25',
#   'Likes': '205',
#   'Published_date': '2022-08-04T18:30:54Z',
#   'Title': "Che cos'è l'embrione sintetico? Un passo verso il futuro #shorts",
#   'Views': '8214'},
#  {'Comments': '61',
#   'Likes': '87',
#   'Published_date': '2022-08-04T17:06:22Z',
#   'Title': 'Claudio Amendola e Francesca Neri si starebbero separando dopo 25 anni insieme: "Si sono lasciati"',
#   'Views': '48380'},
#  {'Comments': '470',
#   'Likes': '672',
#   'Published_date': '2022-08-04T16:00:37Z',
#   'Title': 'Morto Valdir Segato, il bodybuilder che gonfiava i bicipiti con l’olio: “Aiutami, non respiro più”',
#   'Views': '71857'},
#  {'Comments': '146',
#   'Likes': '190',
#   'Published_date': '2022-08-04T15:00:33Z',
#   'Title': 'Wanda Nara e Mauro Icardi stanno divorziando, l’audio con la confessione',
#   'Views': '33419'},
#  {'Comments': '113',
#   'Likes': '276',
#   'Published_date': '2022-08-04T13:00:12Z',
#   'Title': 'Il mare più bello e pulito d’Italia è in Puglia, ultima in classifica l’Abruzzo',
#   'Views': '16211'},
#  {'Comments': '90',
#   'Likes': '35',
#   'Published_date': '2022-08-04T11:39:27Z',
#   'Title': 'Scalfarotto (Iv) a Fanpage.it: "Non so come farà elettore Pd a votare Di Maio, noi soli ma coerenti"',
#   'Views': '3018'},
#  {'Comments': '5',
#   'Likes': '68',
#   'Published_date': '2022-08-04T10:29:23Z',
#   'Title': 'Thomas Ceccon a Fanpage.it: "Dal nonnismo al record del mondo, la mia storia"',
#   'Views': '4102'},
#  {'Comments': '673',
#   'Likes': '567',
#   'Published_date': '2022-08-04T10:20:32Z',
#   'Title': 'Maxi esercitazioni militari della Cina attorno a Taiwan: “Ci prepariamo alla guerra”',
#   'Views': '47222'},
#  {'Comments': '49',
#   'Likes': '306',
#   'Published_date': '2022-08-04T08:53:14Z',
#   'Title': 'Da anni recluso in casa, Lello vince la sua battaglia: "Posso tornare a sentire l\'odore del mare"',
#   'Views': '27717'},
#  {'Comments': '34',
#   'Likes': '80',
#   'Published_date': '2022-08-03T21:30:58Z',
#   'Title': 'Aliscafo sbatte contro banchina a Napoli. Una passeggera: "Pensavamo al peggio, attimi di paura"',
#   'Views': '31302'},
#  {'Comments': '248',
#   'Likes': '306',
#   'Published_date': '2022-08-03T20:00:31Z',
#   'Title': 'Vive in strada con il mio compagno malato: "Il Comune non mi dà una casa, forse perché sono trans?"',
#   'Views': '54743'},
#  {'Comments': '45',
#   'Likes': '83',
#   'Published_date': '2022-08-03T19:00:09Z',
#   'Title': 'Condotte vecchie e acqua razionata a Reggio Calabria: "Costretti a utilizzare serbatoi privati"',
#   'Views': '10162'},
#  {'Comments': '102',
#   'Likes': '568',
#   'Published_date': '2022-08-03T18:00:01Z',
#   'Title': 'Morto Alessandro De Santis, Lillo in Johnny Stecchino: la lettera di cordoglio di Roberto Benigni',
#   'Views': '209659'},
#  {'Comments': '157',
#   'Likes': '260',
#   'Published_date': '2022-08-03T17:00:39Z',
#   'Title': 'Maltrattamenti e abusi sessuali sui pazienti di una Rsa, arrestati 4 OSS a Manfredonia',
#   'Views': '23389'},
#  {'Comments': '190',
#   'Likes': '88',
#   'Published_date': '2022-08-03T16:57:36Z',
#   'Title': '"Ero in fila fuori dalla Questura per i documenti e mi hanno multata", la denuncia di una rifugiata',
#   'Views': '6006'},
#  {'Comments': '47',
#   'Likes': '403',
#   'Published_date': '2022-08-03T16:00:26Z',
#   'Title': 'Una voragine in Cile: di cosa si tratta? #shorts',
#   'Views': '12404'},
#  {'Comments': '521',
#   'Likes': '443',
#   'Published_date': '2022-08-03T15:09:31Z',
#   'Title': 'Cappato si autodenuncia per l\'eutanasia di Elena: "Se ce lo chiederanno aiuteremo ancora"',
#   'Views': '23504'},
#  {'Comments': '221',
#   'Likes': '525',
#   'Published_date': '2022-08-03T14:00:00Z',
#   'Title': 'Francesco Totti fa sul serio con Noemi Bocchi, le foto che raccontano la loro estate romana',
#   'Views': '199280'},
#  {'Comments': '160',
#   'Likes': '830',
#   'Published_date': '2022-08-03T13:16:09Z',
#   'Title': 'Tempesta geomagnetica prevista sulla Terra il 3 agosto: cosa dobbiamo aspettarci',
#   'Views': '45476'},
#  {'Comments': '7',
#   'Likes': '44',
#   'Published_date': '2022-08-03T09:54:09Z',
#   'Title': 'Alice Volpi e Daniele Garozzo, la coppia d\'oro della scherma italiana: "Giriamo il mondo insieme"',
#   'Views': '3165'},
#  {'Comments': '11',
#   'Likes': '77',
#   'Published_date': '2022-08-03T09:00:12Z',
#   'Title': 'Beatrice Gherardini, la beauty star di TikTok e Instagram risponde alle domande di Google',
#   'Views': '2535'},
#  {'Comments': '162',
#   'Likes': '292',
#   'Published_date': '2022-08-02T19:00:13Z',
#   'Title': 'Perchè la carne finta sarebbe meglio di quella vera #shorts',
#   'Views': '9709'},
#  {'Comments': '646',
#   'Likes': '1569',
#   'Published_date': '2022-08-02T17:39:42Z',
#   'Title': 'Fine vita, l’ultimo messaggio di Elena: “Avrei preferito morire nel mio letto, ma sono qui da sola”',
#   'Views': '65221'},
#  {'Comments': '936',
#   'Likes': '2530',
#   'Published_date': '2022-08-02T16:37:15Z',
#   'Title': 'Sorelle travolte da treno, il dolore del padre: “Le accompagnavo sempre io, quella sera stavo male”',
#   'Views': '211289'},
#  {'Comments': '105',
#   'Likes': '294',
#   'Published_date': '2022-08-02T16:00:17Z',
#   'Title': 'Amber Heard dichiara bancarotta e vende casa per poter risarcire Johnny Depp dopo il processo',
#   'Views': '19867'},
#  {'Comments': '341',
#   'Likes': '418',
#   'Published_date': '2022-08-02T14:18:05Z',
#   'Title': 'Gli Stati Uniti hanno ucciso Ayman al-Zawahiri, il capo di Al Qaeda dopo Osama Bin Laden',
#   'Views': '14509'},
#  {'Comments': '68',
#   'Likes': '410',
#   'Published_date': '2022-08-02T13:00:03Z',
#   'Title': 'Bartolucci chiude la bottega di Pinocchio a Roma: "Speriamo in una magia della fata Turchina"',
#   'Views': '20564'},
#  {'Comments': '28',
#   'Likes': '578',
#   'Published_date': '2022-08-02T12:00:25Z',
#   'Title': 'Koulibaly chiama Terry, è quasi imbarazzato: “Posso prendere il numero 26?”. E lui si scioglie',
#   'Views': '17570'},
#  {'Comments': '620',
#   'Likes': '305',
#   'Published_date': '2022-08-02T10:09:02Z',
#   'Title': 'Omicidio Civitanova, Filippo Ferlazzo resta in carcere: “Non pensavo di aver ucciso Alika"',
#   'Views': '33993'},
#  {'Comments': '120',
#   'Likes': '456',
#   'Published_date': '2022-08-02T09:00:25Z',
#   'Title': 'Incendio a Battipaglia, salvato un cane legato alla catena e rimasto bloccato nella cuccia',
#   'Views': '16435'},
#  {'Comments': '56',
#   'Likes': '494',
#   'Published_date': '2022-08-02T07:48:55Z',
#   'Title': 'Strage Bologna, il sopravvissuto Yuri: “Per anni non ho preso treni. La verità? Si può fare di più”',
#   'Views': '43189'},
#  {'Comments': '120',
#   'Likes': '726',
#   'Published_date': '2022-08-01T20:00:09Z',
#   'Title': '“Papà abusava di noi ma dopo il carcere ha diritto alla casa di mamma”, la denuncia di Desirée',
#   'Views': '61191'},
#  {'Comments': '25',
#   'Likes': '138',
#   'Published_date': '2022-08-01T19:30:02Z',
#   'Title': 'Chris Rock ironico sul pugno di Will Smith: “Dopo essere stato picchiato sono andato a lavorare”',
#   'Views': '9785'},
#  {'Comments': '18',
#   'Likes': '112',
#   'Published_date': '2022-08-01T18:21:03Z',
#   'Title': 'È morta Pat Carroll, ha dato la voce ad Ursula ne La Sirenetta Disney: Sono stata una brava cattiva',
#   'Views': '5463'},
#  {'Comments': '234',
#   'Likes': '178',
#   'Published_date': '2022-08-01T18:00:05Z',
#   'Title': "I sintomi sulla pelle del vaiolo delle scimmie, la spiegazione dell'esperto del Cotugno",
#   'Views': '12122'},
#  {'Comments': '42',
#   'Likes': '355',
#   'Published_date': '2022-08-01T17:00:00Z',
#   'Title': 'Perchè la Polonia ha dichiarato i gatti "specie aliena invasiva"? #shorts',
#   'Views': '10980'},
#  {'Comments': '136',
#   'Likes': '492',
#   'Published_date': '2022-08-01T15:01:09Z',
#   'Title': 'Le tolgono il figlio che l\'ex compagno non voleva: "Sono morta il giorno che me l\'hanno portato via"',
#   'Views': '37293'},
#  {'Comments': '78',
#   'Likes': '295',
#   'Published_date': '2022-08-01T12:45:28Z',
#   'Title': "Disastro Ferrari in Formula 1, cos'è successo al GP Ungheria: tutti gli errori di strategia",
#   'Views': '21566'},
#  {'Comments': '1225',
#   'Likes': '2404',
#   'Published_date': '2022-08-01T10:45:24Z',
#   'Title': 'Sorelle travolte dal treno a Riccione, un testimone: “Una voleva salvare l’altra”',
#   'Views': '179682'},
#  {'Comments': '10',
#   'Likes': '121',
#   'Published_date': '2022-08-01T08:29:02Z',
#   'Title': 'Franco Malerba, il primo astronauta italiano nello spazio: "Vi racconto il mio viaggio"',
#   'Views': '2147'},
#  {'Comments': '35',
#   'Likes': '240',
#   'Published_date': '2022-07-31T10:00:29Z',
#   'Title': '"Ho perso e ritrovato mia figlia, ma ora è tardi", l’odissea di Orazio, malato di Parkinson',
#   'Views': '27113'},
#  {'Comments': '1941',
#   'Likes': '2580',
#   'Published_date': '2022-07-30T18:30:54Z',
#   'Title': 'Ambulante ucciso in strada, la moglie di Alika: "Quest\'uomo deve dirmi perché ha ucciso mio marito"',
#   'Views': '143198'},
#  {'Comments': '171',
#   'Likes': '353',
#   'Published_date': '2022-07-30T16:00:13Z',
#   'Title': 'Cancellato all’alba il murales per Nicholas Brischetto: “Era un altarino criminale”',
#   'Views': '36566'},
#  {'Comments': '1159',
#   'Likes': '1287',
#   'Published_date': '2022-07-30T15:49:34Z',
#   'Title': 'Ambulante ucciso in strada a Civitanova. L\'avvocato di Alika: "La moglie chiede giustizia"',
#   'Views': '134618'},
#  {'Comments': '136',
#   'Likes': '372',
#   'Published_date': '2022-07-30T14:31:23Z',
#   'Title': 'Morto l’attore Roberto Nobile, addio a Parmesan di Distretto di Polizia',
#   'Views': '48112'},
#  {'Comments': '98',
#   'Likes': '321',
#   'Published_date': '2022-07-30T14:00:23Z',
#   'Title': 'Cerca la madre biologica da quando ha cinque anni: "Voglio solo abbracciarla"',
#   'Views': '24435'},
#  {'Comments': '134',
#   'Likes': '414',
#   'Published_date': '2022-07-30T12:00:09Z',
#   'Title': 'Le scuse di Will Smith a Chris Rock: “Non vuole parlarmi, ma con lo schiaffo mia moglie non c’entra”',
#   'Views': '22497'},
#  {'Comments': '58',
#   'Likes': '228',
#   'Published_date': '2022-07-30T11:00:35Z',
#   'Title': 'Parla il fratello di Emanuela Orlandi: “La storia di Katty Skerl ci allontana dalla verità”',
#   'Views': '20514'},
#  {'Comments': '3374',
#   'Likes': '2158',
#   'Published_date': '2022-07-30T09:50:13Z',
#   'Title': 'Chi è Filippo Ferlazzo, l’uomo che ha ucciso a bastonate l’ambulante nigeriano a Civitanova Marche',
#   'Views': '448867'},
#  {'Comments': '134',
#   'Likes': '267',
#   'Published_date': '2022-07-29T20:00:24Z',
#   'Title': 'Roma, bagarini ancora al Colosseo: “La polizia li saluta e fa finta di niente"',
#   'Views': '30010'},
#  {'Comments': '563',
#   'Likes': '1644',
#   'Published_date': '2022-07-29T19:53:03Z',
#   'Title': '"Siamo tutti responsabili della morte di una bimba di 16 mesi", Sala ai funerali di Diana Pifferi',
#   'Views': '153236'},
#  {'Comments': '16',
#   'Likes': '264',
#   'Published_date': '2022-07-29T18:00:07Z',
#   'Title': 'Blanco chiama il padre sul palco e canta Notti in bianco abbracciato a lui: “Dovevo farmi perdonare”',
#   'Views': '20836'},
#  {'Comments': '39',
#   'Likes': '439',
#   'Published_date': '2022-07-29T17:00:12Z',
#   'Title': "Oroscopo 2022, le previsioni e i segni fortunati dall'1 al 7 agosto",
#   'Views': '37882'},
#  {'Comments': '747',
#   'Likes': '477',
#   'Published_date': '2022-07-29T15:00:08Z',
#   'Title': 'Aggressione in palestra a Pescara, 50enne ripreso dalle telecamere ma è libero',
#   'Views': '57175'},
#  {'Comments': '160',
#   'Likes': '56',
#   'Published_date': '2022-07-29T14:00:00Z',
#   'Title': 'Elezioni 2022, Malpezzi (PD): "Ora ripartiamo dall\'agenda del Partito Democratico"',
#   'Views': '2563'},
#  {'Comments': '27',
#   'Likes': '142',
#   'Published_date': '2022-07-29T13:00:00Z',
#   'Title': "Paolo Camilli, l'attore e creator su TikTok e Instagram risponde alle domande di Google",
#   'Views': '3253'},
#  {'Comments': '190',
#   'Likes': '292',
#   'Published_date': '2022-07-29T12:00:12Z',
#   'Title': 'Francesco Totti pronto a parlare: “A Ilary ho dato tutto quello che potevo”',
#   'Views': '120164'},
#  {'Comments': '908',
#   'Likes': '1096',
#   'Published_date': '2022-07-29T10:09:23Z',
#   'Title': 'Arrestato il rapper Simba La Rue: è accusato del sequestro di Baby Touché',
#   'Views': '76623'},
#  {'Comments': '273',
#   'Likes': '106',
#   'Published_date': '2022-07-29T10:00:06Z',
#   'Title': 'Elezioni 2022, la "strategia" della destra per la pandemia: "Il Covid lo mandiamo a quel Paese"',
#   'Views': '8884'},
#  {'Comments': '52',
#   'Likes': '171',
#   'Published_date': '2022-07-29T09:00:00Z',
#   'Title': 'A Torino i viali sono invasi di foglie morte come ad ottobre: "L\'autunno è arrivato a luglio"',
#   'Views': '27225'},
#  {'Comments': '61',
#   'Likes': '52',
#   'Published_date': '2022-07-28T17:00:13Z',
#   'Title': 'Termovalorizzatore, l\'assessora Alfonsi: "Chi critica non dà alternative, M5S voleva maxi discarica"',
#   'Views': '3854'},
#  {'Comments': '670',
#   'Likes': '224',
#   'Published_date': '2022-07-28T16:00:16Z',
#   'Title': '“Anch’io sono Giorgia, ma non rompo i cog***oni”, sfogo della cantante contro Meloni',
#   'Views': '18128'},
#  {'Comments': '92',
#   'Likes': '616',
#   'Published_date': '2022-07-28T16:00:04Z',
#   'Title': 'Vettel annuncia il ritiro dalla F1: “Voglio vedere crescere i miei figli”',
#   'Views': '20345'},
#  {'Comments': '57',
#   'Likes': '258',
#   'Published_date': '2022-07-28T14:00:19Z',
#   'Title': 'Vaiolo delle scimmie: sintomi, trasmissione e cosa sapere',
#   'Views': '8591'},
#  {'Comments': '48',
#   'Likes': '279',
#   'Published_date': '2022-07-28T13:25:25Z',
#   'Title': 'Abbiamo finito tutto. #overshootday #shorts',
#   'Views': '8676'},
#  {'Comments': '138',
#   'Likes': '405',
#   'Published_date': '2022-07-28T13:00:40Z',
#   'Title': 'Valentina Giunta uccisa dal figlio 15enne perché voleva allontanarlo dal padre',
#   'Views': '41156'},
#  {'Comments': '817',
#   'Likes': '642',
#   'Published_date': '2022-07-28T12:00:11Z',
#   'Title': 'Si schianta sul Raccordo a 300 km/h: neomelodico, auto di lusso e champagne al funerale di Nicholas',
#   'Views': '107252'},
#  {'Comments': '214',
#   'Likes': '527',
#   'Published_date': '2022-07-28T10:55:37Z',
#   'Title': 'Torino, lite tra Juric e Vagnati nel parcheggio: il video della rissa',
#   'Views': '52523'},
#  {'Comments': '64',
#   'Likes': '35',
#   'Published_date': '2022-07-28T08:56:58Z',
#   'Title': 'A Napoli il festival di Mediterranea Saving Humans: "Salvini e la sua propaganda non ci spaventano"',
#   'Views': '1446'},
#  {'Comments': '47',
#   'Likes': '71',
#   'Published_date': '2022-07-27T18:00:18Z',
#   'Title': "Cosa rischia Palomino dopo la positività all'antidoping: può salvarlo una pomata della moglie",
#   'Views': '7261'},
#  {'Comments': '25',
#   'Likes': '110',
#   'Published_date': '2022-07-27T16:00:42Z',
#   'Title': 'Dybala è già come Totti: scatta lo stesso selfie del Capitano e conquista i tifosi della Roma',
#   'Views': '21023'},
#  {'Comments': '74',
#   'Likes': '466',
#   'Published_date': '2022-07-27T13:59:38Z',
#   'Title': 'È morto l’attore Antonio Casagrande, papà di Maurizio: aveva 91 anni',
#   'Views': '125029'},
#  {'Comments': '208',
#   'Likes': '767',
#   'Published_date': '2022-07-27T11:41:36Z',
#   'Title': 'Come iscriversi al Registro Pubblico delle Opposizioni per lo stop al telemarketing sul cellulare',
#   'Views': '62917'},
#  {'Comments': '41',
#   'Likes': '321',
#   'Published_date': '2022-07-27T11:39:07Z',
#   'Title': 'Perché Liberato non è Gennaro Nocerino (non solo, perlomeno)',
#   'Views': '24163'},
#  {'Comments': '54',
#   'Likes': '239',
#   'Published_date': '2022-07-27T10:14:59Z',
#   'Title': "Terremoto Filippine, scossa di magnitudo 7 sull'isola di Luzon: ci sono vittime",
#   'Views': '13964'},
#  {'Comments': '134',
#   'Likes': '103',
#   'Published_date': '2022-07-26T20:00:11Z',
#   'Title': 'Incatenati contro la crisi climatica, 5 fogli di via: “Sono di Torino, non posso tornare a casa mia”',
#   'Views': '7460'},
#  {'Comments': '50',
#   'Likes': '137',
#   'Published_date': '2022-07-26T19:59:25Z',
#   'Title': 'Omicidio Gualzetti, il papà di Chiara dopo la sentenza: “Avremmo voluto di più ma giustizia è fatta”',
#   'Views': '8832'},
#  {'Comments': '59',
#   'Likes': '241',
#   'Published_date': '2022-07-26T19:25:46Z',
#   'Title': 'A Ponticelli i funerali di Antimo Imperatore, vittima innocente di camorra: "Promettiamo di darti gi',
#   'Views': '37578'},
#  {'Comments': '15',
#   'Likes': '154',
#   'Published_date': '2022-07-26T19:00:07Z',
#   'Title': "Haven Shepherd, la nuotatrice paralimpica sopravvissuta all'esplosione di una bomba",
#   'Views': '10363'},
#  {'Comments': '353',
#   'Likes': '228',
#   'Published_date': '2022-07-26T18:00:11Z',
#   'Title': 'La storia di Ilaria Rimoldi: "Con OnlyFans guadagno 2000 euro al mese e nessuno deve giudicarmi"',
#   'Views': '55654'},
#  {'Comments': '179',
#   'Likes': '63',
#   'Published_date': '2022-07-26T17:00:38Z',
#   'Title': 'Elezioni, incontro tra Letta, Di Maio e Sala. Il sindaco di Milano: "Non mi candido, ma dò una mano"',
#   'Views': '9258'},
#  {'Comments': '8',
#   'Likes': '64',
#   'Published_date': '2022-07-26T16:00:09Z',
#   'Title': 'Delfini ad Ostia, siamo usciti in barca per conoscerli con chi li studia e tutela',
#   'Views': '4520'},
#  {'Comments': '158',
#   'Likes': '323',
#   'Published_date': '2022-07-26T15:06:50Z',
#   'Title': 'Selfie del killer e offese dal carcere, il papà di Chiara Gualzetti a Fanpage: “Colpito e sdegnato”',
#   'Views': '29886'},
#  {'Comments': '200',
#   'Likes': '137',
#   'Published_date': '2022-07-26T15:00:01Z',
#   'Title': 'Vaiolo delle scimmie in Europa e Italia: sintomi, trasmissione e come prevenirlo',
#   'Views': '17257'},
#  {'Comments': '31',
#   'Likes': '54',
#   'Published_date': '2022-07-26T14:00:19Z',
#   'Title': 'Amazon Prime aumenta l’abbonamento mensile e annuale: quanto costerà e perché si pagherà di più',
#   'Views': '4141'},
#  {'Comments': '195',
#   'Likes': '516',
#   'Published_date': '2022-07-26T13:00:05Z',
#   'Title': 'Finisce di lavorare in un bar e ha un incidente in auto: Greta Curti muore a 21 anni',
#   'Views': '36786'},
#  {'Comments': '32',
#   'Likes': '208',
#   'Published_date': '2022-07-26T12:00:45Z',
#   'Title': 'Undici anni fa l\'omicidio di Edoardo Sforna. L\'appello dei genitori: "Il killer ancora senza nome"',
#   'Views': '14057'},
#  {'Comments': '184',
#   'Likes': '646',
#   'Published_date': '2022-07-26T10:09:55Z',
#   'Title': 'Trovata morta nella doccia dopo un mese: il suo cane in fin di vita le è stato vicino tutto il tempo',
#   'Views': '32284'},
#  {'Comments': '49',
#   'Likes': '103',
#   'Published_date': '2022-07-26T07:01:50Z',
#   'Title': 'Lutto per Roberto Farnesi, morta la madre Maria. La dedica alla figlia: “Meno male che ci sei”',
#   'Views': '16311'},
#  {'Comments': '172',
#   'Likes': '3457',
#   'Published_date': '2022-07-25T19:00:00Z',
#   'Title': 'Cosa succede ai bagagli in un aereo? Abbiamo passato 24 ore con la Guardia di Finanza in aeroporto',
#   'Views': '242139'},
#  {'Comments': '332',
#   'Likes': '131',
#   'Published_date': '2022-07-25T17:00:05Z',
#   'Title': 'Calenda: "Da Pd due anni di idiozie su M5S, ora ci dica se sta con noi per riportare Draghi a Chigi"',
#   'Views': '9770'},
#  {'Comments': '6',
#   'Likes': '58',
#   'Published_date': '2022-07-25T16:00:26Z',
#   'Title': 'La Modella Assassina - La storia di Rosa Della Corte su Crime+Investigation: video promo della serie',
#   'Views': '4919'},
#  {'Comments': '118',
#   'Likes': '341',
#   'Published_date': '2022-07-25T15:30:03Z',
#   'Title': 'Affonda un pedalò con cinque ragazzi: salvati da Vita e Dylan, i cani bagnino di Palinuro',
#   'Views': '13525'},
#  {'Comments': '14',
#   'Likes': '230',
#   'Published_date': '2022-07-25T15:29:28Z',
#   'Title': 'Bonus psicologo, domande al via: come richiederlo sul sito Inps #shorts',
#   'Views': '5859'},
#  {'Comments': '114',
#   'Likes': '105',
#   'Published_date': '2022-07-25T15:00:04Z',
#   'Title': 'Attacco hacker all’Agenzia delle Entrate, rubati dati e chiesto il riscatto: indagini in corso',
#   'Views': '7770'},
#  {'Comments': '111',
#   'Likes': '71',
#   'Published_date': '2022-07-25T14:00:12Z',
#   'Title': 'Anna Kim, ucraina in Italia: "Ho fermato studi e lavoro per aiutare i miei concittadini in guerra"',
#   'Views': '4017'},
#  {'Comments': '212',
#   'Likes': '290',
#   'Published_date': '2022-07-25T13:00:31Z',
#   'Title': 'Come evitare di prendere il vaiolo delle scimmie in vacanza e a cosa bisogna stare attenti',
#   'Views': '14128'},
#  {'Comments': '72',
#   'Likes': '428',
#   'Published_date': '2022-07-25T12:00:29Z',
#   'Title': 'La "partita con papà" dentro al carcere di Catania: detenuti e figli giocano insieme',
#   'Views': '28107'},
#  {'Comments': '171',
#   'Likes': '279',
#   'Published_date': '2022-07-25T11:00:36Z',
#   'Title': 'A Jesolo con 99 euro si mangia la pizza d\'oro: "Ecco perché costa così tanto"',
#   'Views': '15122'},
#  {'Comments': '630',
#   'Likes': '550',
#   'Published_date': '2022-07-25T10:13:53Z',
#   'Title': 'Alessia Pifferi ha partorito Diana in bagno: la breve e triste vita della bimba uccisa dalla madre',
#   'Views': '40984'},
#  {'Comments': '178',
#   'Likes': '1514',
#   'Published_date': '2022-07-24T13:06:31Z',
#   'Title': 'Neima Ezza: "La musica ha dato una possibilità a un quartiere in cui è meglio viverci che morirci”',
#   'Views': '28420'},
#  {'Comments': '937',
#   'Likes': '1067',
#   'Published_date': '2022-07-23T11:54:56Z',
#   'Title': 'Bimba morta di stenti, i vicini alla fiaccolata: "Nessuno ha segnalato il disagio della madre, l\'avr',
#   'Views': '66402'},
#  {'Comments': '22',
#   'Likes': '176',
#   'Published_date': '2022-07-23T10:00:13Z',
#   'Title': 'Ramini, argento ai mondiali di Paraclimbing: "Dopo il coma, provo un senso atomico di libertà"',
#   'Views': '10717'},
#  {'Comments': '237',
#   'Likes': '658',
#   'Published_date': '2022-07-23T08:00:06Z',
#   'Title': 'Don Giuseppe sospeso e denunciato: "Volevo solo regalare le mie piantine di cannabis legale online"',
#   'Views': '47185'},
#  {'Comments': '607',
#   'Likes': '151',
#   'Published_date': '2022-07-23T06:00:13Z',
#   'Title': 'Muri imbrattati da scritte omofobe, l\'ordinanza del sindaco: "Multa da 500 euro a chi discrimina"',
#   'Views': '7336'},
#  {'Comments': '98',
#   'Likes': '75',
#   'Published_date': '2022-07-22T20:00:03Z',
#   'Title': "Archiviata l'accusa di molestie per Ricky Martin, lo sfogo: “È stato devastante”",
#   'Views': '13182'},
#  {'Comments': '43',
#   'Likes': '171',
#   'Published_date': '2022-07-22T19:00:20Z',
#   'Title': '"Da bambino mi chiamavano mostro": la forza di James, che lotta per un mondo più inclusivo',
#   'Views': '10506'},
#  {'Comments': '133',
#   'Likes': '1511',
#   'Published_date': '2022-07-22T18:00:14Z',
#   'Title': 'Lavezzi a Fanpage.it: “Potevo giocare ancora in Italia, non l’ho fatto per rispetto del Napoli”',
#   'Views': '57958'},
#  {'Comments': '556',
#   'Likes': '1431',
#   'Published_date': '2022-07-22T17:02:56Z',
#   'Title': 'Omicidio del piccolo Evan, la madre e il compagno condannati all’ergastolo',
#   'Views': '138017'},
#  {'Comments': '19',
#   'Likes': '245',
#   'Published_date': '2022-07-22T17:00:26Z',
#   'Title': 'Oroscopo settimanale 25-31 luglio 2022, le previsioni e i segni fortunati',
#   'Views': '9436'},
#  {'Comments': '931',
#   'Likes': '488',
#   'Published_date': '2022-07-22T16:06:51Z',
#   'Title': 'Alessia Pifferi: “Avevo già lasciato altre volte mia figlia Diana da sola”',
#   'Views': '68846'},
#  {'Comments': '133',
#   'Likes': '170',
#   'Published_date': '2022-07-22T16:00:03Z',
#   'Title': 'La prof del corsivo Elisa Esposito non parteciperà al GF Vip 7: “Ho deciso io di rinunciare”',
#   'Views': '24962'},
#  {'Comments': '1126',
#   'Likes': '428',
#   'Published_date': '2022-07-22T15:00:37Z',
#   'Title': 'Il matrimonio tra la carabiniera Elena e la sua Claudia: “Abbiate il coraggio di amare”',
#   'Views': '17511'},
#  {'Comments': '129',
#   'Likes': '422',
#   'Published_date': '2022-07-22T14:00:10Z',
#   'Title': 'Duplice omicidio a Ponticelli, in pochi al presidio per Antimo Imperatore, ucciso per errore',
#   'Views': '49068'},
#  {'Comments': '206',
#   'Likes': '1566',
#   'Published_date': '2022-07-22T12:00:29Z',
#   'Title': 'Sua madre è stata uccisa dal padre, lo Stato lo abbandona: la storia di Stefano Truzzi',
#   'Views': '75115'},
#  {'Comments': '263',
#   'Likes': '1565',
#   'Published_date': '2022-07-22T11:00:23Z',
#   'Title': 'Il carabiniere che ha salvato una bimba bloccata in auto: "Bisognava agire subito e l\'ho fatto"',
#   'Views': '94007'},
#  {'Comments': '48',
#   'Likes': '80',
#   'Published_date': '2022-07-22T10:00:11Z',
#   'Title': 'La confessione del rapper Diablo Baby: "Le liti tra gang? Molte sono false"',
#   'Views': '4616'},
#  {'Comments': '38',
#   'Likes': '129',
#   'Published_date': '2022-07-22T09:00:19Z',
#   'Title': 'Epidemia nelle bufale, la rivolta degli allevatori: "Il piano di De Luca ha fallito"',
#   'Views': '21261'},
#  {'Comments': '897',
#   'Likes': '784',
#   'Published_date': '2022-07-22T05:41:52Z',
#   'Title': "Bimba morta di stenti a Milano, Diana aveva 16 mesi: la mamma Alessia Pifferi l'ha lasciata sola",
#   'Views': '80162'},
#  {'Comments': '49',
#   'Likes': '217',
#   'Published_date': '2022-07-21T20:00:07Z',
#   'Title': 'Si finge infermiera, ruba un neonato in ospedale e poi fugge: chi è la ladra di bambini',
#   'Views': '19667'},
#  {'Comments': '325',
#   'Likes': '159',
#   'Published_date': '2022-07-21T19:00:22Z',
#   'Title': 'Usa, polizia uccide un 23enne afroamericano: “Una orribile esecuzione”',
#   'Views': '11612'},
#  {'Comments': '646',
#   'Likes': '915',
#   'Published_date': '2022-07-21T18:00:15Z',
#   'Title': 'Vittoria e Matteo su OnlyFans sono Shinratensei98: "Ecco le richieste più strane che ci hanno fatto"',
#   'Views': '233920'},
#  {'Comments': '37',
#   'Likes': '123',
#   'Published_date': '2022-07-21T17:41:23Z',
#   'Title': 'Incendi, brucia il Carso: “Livelli PM10 oltre 300 e case in fiamme, non sappiamo come andrà”',
#   'Views': '7822'},
#  {'Comments': '279',
#   'Likes': '221',
#   'Published_date': '2022-07-21T17:09:04Z',
#   'Title': 'Mattarella: “Scioglimento Camere è ultimo atto”. Ecco la data ufficiale del voto anticipato',
#   'Views': '13005'},
#  {'Comments': '102',
#   'Likes': '406',
#   'Published_date': '2022-07-21T17:00:35Z',
#   'Title': 'Kharkiv, padre non lascia la mano del figlio 13enne ucciso in strada',
#   'Views': '38196'},
#  {'Comments': '27',
#   'Likes': '50',
#   'Published_date': '2022-07-21T16:00:35Z',
#   'Title': 'Bianca Atzei e Stefano Corti diventeranno genitori: “Ti daremo tutto il nostro amore"',
#   'Views': '7139'},
#  {'Comments': '583',
#   'Likes': '545',
#   'Published_date': '2022-07-21T16:00:14Z',
#   'Title': 'Crisi di Governo, il discorso di Mattarella dopo le dimissioni di Draghi in diretta',
#   'Views': '42299'},
#  {'Comments': '35',
#   'Likes': '129',
#   'Published_date': '2022-07-21T14:55:23Z',
#   'Title': 'Morto Luca Serianni, linguista e professore della Sapienza: investito mentre attraversava la strada',
#   'Views': '20051'},
#  {'Comments': '2',
#   'Likes': '59',
#   'Published_date': '2022-07-21T14:51:37Z',
#   'Title': 'Il gusto della libertà: il racconto di Camila Raznovich',
#   'Views': '2372'},
#  {'Comments': '6',
#   'Likes': '37',
#   'Published_date': '2022-07-21T14:36:17Z',
#   'Title': 'Impianto di compostaggio a Napoli est, apertura nel 2024: "Lo aspettavamo da 10 anni"',
#   'Views': '6397'},
#  {'Comments': '38',
#   'Likes': '229',
#   'Published_date': '2022-07-21T14:17:22Z',
#   'Title': "La guerra a Napoli: lo scenario simulato dall'Accademia Aeronautica",
#   'Views': '8818'},
#  {'Comments': '57',
#   'Likes': '175',
#   'Published_date': '2022-07-21T13:32:11Z',
#   'Title': 'Governo Draghi, il premier annuncia le dimissioni alla Camera dopo la fiducia al Senato',
#   'Views': '14517'},
#  {'Comments': '235',
#   'Likes': '163',
#   'Published_date': '2022-07-21T13:31:13Z',
#   'Title': 'Crisi governo, Zanda (Pd): "Far cadere Draghi è criminalità politica"',
#   'Views': '6872'},
#  {'Comments': '89',
#   'Likes': '309',
#   'Published_date': '2022-07-21T13:00:44Z',
#   'Title': 'Il comandante generale dei carabinieri a Fanpage.it: "Così il Covid ha cambiato volto al crimine"',
#   'Views': '21194'},
#  {'Comments': '16',
#   'Likes': '109',
#   'Published_date': '2022-07-21T12:15:45Z',
#   'Title': 'Abbiamo provato il nuovo MacBook Air con chip M2',
#   'Views': '3322'},
#  {'Comments': '351',
#   'Likes': '1063',
#   'Published_date': '2022-07-21T11:00:12Z',
#   'Title': 'Mario Draghi si è dimesso, cosa succede al Governo e che farà Mattarella  #shorts',
#   'Views': '92787'},
#  {'Comments': '481',
#   'Likes': '312',
#   'Published_date': '2022-07-21T09:11:05Z',
#   'Title': 'Standing ovation e applausi per Draghi alla Camera: "Anche il cuore dei banchieri viene usato"',
#   'Views': '26087'},
#  {'Comments': '626',
#   'Likes': '420',
#   'Published_date': '2022-07-21T08:33:36Z',
#   'Title': 'Mario Draghi annuncia le dimissioni, Mattarella le accetta: la dichiarazione ufficiale del Quirinale',
#   'Views': '39211'},
#  {'Comments': '196',
#   'Likes': '118',
#   'Published_date': '2022-07-20T21:30:10Z',
#   'Title': 'Crisi di governo, Giorgetti: "Poteva finire in modo più dignitoso". Serracchiani: "Elezioni probabil',
#   'Views': '9762'},
#  {'Comments': '184',
#   'Likes': '135',
#   'Published_date': '2022-07-20T20:57:40Z',
#   'Title': 'Crisi di governo, Conte: "Il M5s è stato messo alla porta"',
#   'Views': '8816'},
#  {'Comments': '114',
#   'Likes': '83',
#   'Published_date': '2022-07-20T19:53:00Z',
#   'Title': 'Sequestrate 34 piante di cannabis terapeutica: "Rischiamo 260mila euro di multa per aiutare i malati',
#   'Views': '3551'},
#  {'Comments': '137',
#   'Likes': '350',
#   'Published_date': '2022-07-20T18:42:59Z',
#   'Title': 'Crisi governo, Draghi ottiene fiducia al Senato, Lega, M5S e FI non votano: verso le dimissioni',
#   'Views': '37208'},
#  {'Comments': '55',
#   'Likes': '367',
#   'Published_date': '2022-07-20T18:12:01Z',
#   'Title': 'Crisi di Governo, cosa è successo dopo il discorso di Draghi in Senato #shorts',
#   'Views': '17640'},
#  {'Comments': '489',
#   'Likes': '198',
#   'Published_date': '2022-07-20T16:57:42Z',
#   'Title': 'Bakayoko racconta una nuova verità sulla polizia: “Nel video non si vede tutto, ero in pericolo”',
#   'Views': '18072'},
#  {'Comments': '278',
#   'Likes': '556',
#   'Published_date': '2022-07-20T16:23:08Z',
#   'Title': 'Duplice omicidio a Napoli, la famiglia di Antimo: "Innocente, morto mentre lavorava per pochi euro"',
#   'Views': '67008'},
#  {'Comments': '28',
#   'Likes': '86',
#   'Published_date': '2022-07-20T15:45:00Z',
#   'Title': "Bremer alla Juve, beffata l'Inter: tutti i dettagli della trattativa con il Torino",
#   'Views': '5117'},
#  {'Comments': '52',
#   'Likes': '328',
#   'Published_date': '2022-07-20T15:34:10Z',
#   'Title': 'Governo Draghi, il voto di fiducia al Senato in diretta: attesa la replica del premier',
#   'Views': '39187'},
#  {'Comments': '98',
#   'Likes': '66',
#   'Published_date': '2022-07-20T15:15:00Z',
#   'Title': 'Il video di Alexandria Ocasio-Cortez arrestata durante protesta a favore dell’aborto a Washington',
#   'Views': '7175'},
#  {'Comments': '0',
#   'Likes': '7',
#   'Published_date': '2022-07-20T15:04:54Z',
#   'Title': 'Governo Draghi, il voto di fiducia al Senato in diretta: attesa la replica del premier',
#   'Views': '0'},
#  {'Comments': '487',
#   'Likes': '391',
#   'Published_date': '2022-07-20T14:30:14Z',
#   'Title': 'Crisi di governo, il discorso di Draghi in Senato: “Con nuovo patto politico di fiducia io resto”',
#   'Views': '26043'},
#  {'Comments': '42',
#   'Likes': '87',
#   'Published_date': '2022-07-20T13:33:14Z',
#   'Title': 'Il 24% dei bambini sviluppa il Long Covid, lo studio italiano: "Sintomi lievi, guarisce in 2-9 mesi"',
#   'Views': '3620'},
#  {'Comments': '294',
#   'Likes': '205',
#   'Published_date': '2022-07-20T11:34:14Z',
#   'Title': 'La Lega non applaude il discorso di Draghi, Giorgetti: "Su fiducia non abbiamo ancora deciso"',
#   'Views': '22007'},
#  {'Comments': '102',
#   'Likes': '291',
#   'Published_date': '2022-07-20T10:00:03Z',
#   'Title': 'Crisi di Governo: la decisione di Draghi in Senato #shorts',
#   'Views': '17612'},
#  {'Comments': '479',
#   'Likes': '597',
#   'Published_date': '2022-07-20T08:25:24Z',
#   'Title': 'Il discorso integrale di Draghi al Senato: "Ricostruire patto fiducia"',
#   'Views': '41411'},
#  {'Comments': '51',
#   'Likes': '305',
#   'Published_date': '2022-07-19T18:00:05Z',
#   'Title': 'Vive senza un occhio dopo esser sopravvissuta a un tumore: la storia di Flynn, la cagnolina coraggio',
#   'Views': '11792'},
#  {'Comments': '35',
#   'Likes': '292',
#   'Published_date': '2022-07-19T17:00:36Z',
#   'Title': 'Anna Maisetti, dopo il cancro il linfedema: "Anche nelle difficoltà non bisogna arrendersi"',
#   'Views': '63996'},
#  {'Comments': '259',
#   'Likes': '944',
#   'Published_date': '2022-07-19T14:00:01Z',
#   'Title': 'Invitato spara col fucile per festeggiare il matrimonio: colpisce la sposa alla testa e la uccide',
#   'Views': '77238'},
#  {'Comments': '3',
#   'Likes': '198',
#   'Published_date': '2022-07-19T13:00:21Z',
#   'Title': 'Come sparare ragnatele stile Spiderman a Disneyland Paris #shorts',
#   'Views': '5124'},
#  {'Comments': '155',
#   'Likes': '1011',
#   'Published_date': '2022-07-19T12:00:12Z',
#   'Title': 'La storia di Martin, diplomato un anno prima: “Non sono né un genio, né un secchione”',
#   'Views': '52968'},
#  {'Comments': '133',
#   'Likes': '964',
#   'Published_date': '2022-07-19T11:00:26Z',
#   'Title': 'Giuseppe a 99 anni si laurea in filosofia con 110 e lode, ora scriverà un libro',
#   'Views': '31142'},
#  {'Comments': '231',
#   'Likes': '2635',
#   'Published_date': '2022-07-19T09:43:52Z',
#   'Title': "Trent'anni da Via D'Amelio, Sandro Ruotolo racconta depistaggi e bugie sulla morte di Borsellino",
#   'Views': '152093'},
#  {'Comments': '631',
#   'Likes': '162',
#   'Published_date': '2022-07-19T07:01:59Z',
#   'Title': 'Crisi di Governo, politici e cittadini chiedono a Draghi di restare: "Siamo l\'Italia seria"',
#   'Views': '11001'},
#  {'Comments': '81',
#   'Likes': '470',
#   'Published_date': '2022-07-18T18:00:17Z',
#   'Title': 'Ivano Monzani soccorre una ragazza che si sente male a un concerto e parte l’ovazione',
#   'Views': '38943'},
#  {'Comments': '7',
#   'Likes': '61',
#   'Published_date': '2022-07-18T17:00:06Z',
#   'Title': "Abbiamo visitato in anteprima l'Avengers Campus di Disneyland Paris",
#   'Views': '3542'},
#  {'Comments': '84',
#   'Likes': '282',
#   'Published_date': '2022-07-18T14:27:09Z',
#   'Title': 'Jennifer Lopez e Ben Affleck si sono sposati, le foto e i video del matrimonio a sorpresa',
#   'Views': '23008'},
#  {'Comments': '882',
#   'Likes': '562',
#   'Published_date': '2022-07-18T12:00:09Z',
#   'Title': 'Bakayoko fermato e perquisito dalla polizia con pistola puntata: la Questura: "È stato un malinteso"',
#   'Views': '80383'},
#  {'Comments': '3201',
#   'Likes': '1607',
#   'Published_date': '2022-07-18T11:04:57Z',
#   'Title': 'Bacio fra due modelle ai Quartieri Spagnoli, la suora si infuria e le allontana: “È il diavolo…”',
#   'Views': '104307'},
#  {'Comments': '23',
#   'Likes': '177',
#   'Published_date': '2022-07-18T08:46:44Z',
#   'Title': 'Gino Bartali, il ciclista eroe',
#   'Views': '3654'},
#  {'Comments': '129',
#   'Likes': '392',
#   'Published_date': '2022-07-17T15:00:01Z',
#   'Title': 'Vittoria Lucia chiama Fedez “papà” per la prima volta in diretta, la reazione di Federico',
#   'Views': '20241'},
#  {'Comments': '1146',
#   'Likes': '364',
#   'Published_date': '2022-07-17T13:03:00Z',
#   'Title': 'Salento Pride a Lecce: dopo otto anni tornano i colori arcobaleno in città',
#   'Views': '11291'},
#  {'Comments': '114',
#   'Likes': '101',
#   'Published_date': '2022-07-17T12:22:19Z',
#   'Title': 'Ricky Martin accusato di molestie, il fratello lo difende: “Nostro nipote ha problemi mentali”',
#   'Views': '31208'},
#  {'Comments': '414',
#   'Likes': '408',
#   'Published_date': '2022-07-17T10:23:41Z',
#   'Title': 'Anzio, Leonardo muore a 26 anni accoltellato durante una rissa tra i locali della movida',
#   'Views': '45545'},
#  {'Comments': '486',
#   'Likes': '425',
#   'Published_date': '2022-07-17T09:13:27Z',
#   'Title': 'Bimbo di 7 anni morto a Frosinone per Covid, la Asl: “Troppo grave per salire in eliambulanza”',
#   'Views': '57481'},
#  {'Comments': '355',
#   'Likes': '1737',
#   'Published_date': '2022-07-16T15:58:50Z',
#   'Title': 'Bomba alla pescheria di Peppe Di Napoli a Pianura. Il commerciante-social: "Resto qui, non ho paura"',
#   'Views': '284565'},
#  {'Comments': '315',
#   'Likes': '198',
#   'Published_date': '2022-07-16T13:01:50Z',
#   'Title': 'I Mottola dopo l\'assoluzione: "Con l\'omicidio di Serena Mollicone non c\'entriamo niente"',
#   'Views': '23620'},
#  {'Comments': '69',
#   'Likes': '268',
#   'Published_date': '2022-07-16T11:00:28Z',
#   'Title': 'Prete sfida la camorra con un megafono nelle piazze di spaccio e sotto casa del boss: "Via da qui"',
#   'Views': '13286'},
#  {'Comments': '186',
#   'Likes': '424',
#   'Published_date': '2022-07-16T10:00:08Z',
#   'Title': '"Vergogna, assassini": urla e insulti ai Mottola, assolti al processo Serena Mollicone',
#   'Views': '19873'},
#  {'Comments': '320',
#   'Likes': '197',
#   'Published_date': '2022-07-16T08:54:26Z',
#   'Title': 'Processo Mollicone: tutti assolti. I Mottola si abbracciano in aula dopo la sentenza',
#   'Views': '20757'},
#  {'Comments': '225',
#   'Likes': '163',
#   'Published_date': '2022-07-16T08:00:14Z',
#   'Title': 'La prima italiana di seconda generazione eletta consigliera a Verona: "Spero di essere un\'apripista"',
#   'Views': '6626'},
#  {'Comments': '11',
#   'Likes': '58',
#   'Published_date': '2022-07-16T07:09:08Z',
#   'Title': 'Due anni dalla morte di Mario Paciolla, la mamma: "Il nuovo governo colombiano ci aiuti"',
#   'Views': '4301'},
#  {'Comments': '20',
#   'Likes': '344',
#   'Published_date': '2022-07-15T19:00:09Z',
#   'Title': 'Cosa succede se perdiamo i nostri ghiacciai? #shorts #fanpage #marmolada',
#   'Views': '9258'},
#  {'Comments': '152',
#   'Likes': '241',
#   'Published_date': '2022-07-15T18:00:11Z',
#   'Title': 'Verso stop agli animali nei circhi italiani: approvata legge delega',
#   'Views': '9671'},
#  {'Comments': '26',
#   'Likes': '288',
#   'Published_date': '2022-07-15T17:00:04Z',
#   'Title': 'Oroscopo settimanale 18-14 luglio 2022, la classifica dei segni fortunati',
#   'Views': '8655'},
#  {'Comments': '245',
#   'Likes': '1010',
#   'Published_date': '2022-07-15T16:59:21Z',
#   'Title': 'Omicidio Mollicone, i genitori di Marco Vannini: "Oggi rappresentiamo la mamma e il papà di Serena"',
#   'Views': '130156'},
#  {'Comments': '128',
#   'Likes': '310',
#   'Published_date': '2022-07-15T16:35:54Z',
#   'Title': 'Bimbi tolti alla madre: "Può succedere a tutti, volevo proteggerli dal padre"',
#   'Views': '13670'},
#  {'Comments': '69',
#   'Likes': '154',
#   'Published_date': '2022-07-15T12:00:20Z',
#   'Title': "Il Pantheon ostaggio di bagarini e finte guide: guadagnano 450 euro l'ora, ovviamente a nero",
#   'Views': '7323'},
#  {'Comments': '293',
#   'Likes': '205',
#   'Published_date': '2022-07-15T09:30:52Z',
#   'Title': 'Crisi di governo, cosa succede adesso. Conte: "Confronto aperto", la Lega: "Via maestra è il voto"',
#   'Views': '14797'},
#  {'Comments': '180',
#   'Likes': '438',
#   'Published_date': '2022-07-15T07:20:18Z',
#   'Title': 'Morta Ivana Trump, prima moglie dell’ex presidente Usa: aveva 73 anni',
#   'Views': '55116'},
#  {'Comments': '213',
#   'Likes': '889',
#   'Published_date': '2022-07-14T19:00:17Z',
#   'Title': 'Perché Mario Draghi si è dimesso da Presidente del Consiglio #shorts',
#   'Views': '44316'},
#  {'Comments': '503',
#   'Likes': '253',
#   'Published_date': '2022-07-14T18:30:35Z',
#   'Title': 'Mario Draghi si è dimesso da presidente del Consiglio',
#   'Views': '15353'},
#  {'Comments': '16',
#   'Likes': '170',
#   'Published_date': '2022-07-14T18:00:13Z',
#   'Title': "La Superluna piena del Cervo brilla nei cieli d'Italia a luglio 2022: le splendide immagini",
#   'Views': '6031'},
# ...
#   'Title': '"Berlino distrutta in 106 secondi, Parigi in 200, Londra in 202" #shorts',
#   'Views': '21737'},
#  {'Comments': '15',
#   'Likes': '113',
#   'Published_date': '2022-05-02T10:12:29Z',
#   'Title': 'La storia di Bax, dalla musica ai cavalli scalzi: "Tolgo i ferri e li rieduco alla natura"\'',
#   'Views': '4687'},
#  {'Comments': '904',
#   'Likes': '8739',
#   'Published_date': '2022-05-02T09:48:01Z',
#   'Title': 'Maresciallo salva bimba autistica dai maltrattamenti a scuola: “Il suo sorriso mi ha commosso”',
#   'Views': '645135'},
#  {'Comments': '106',
#   'Likes': '61',
#   'Published_date': '2022-05-01T13:01:25Z',
#   'Title': 'Primo Maggio a Napoli al fianco degli ucraini: "Sotto le bombe si continua a lavorare"',
#   'Views': '3415'},
#  {'Comments': '1315',
#   'Likes': '583',
#   'Published_date': '2022-05-01T08:42:13Z',
#   'Title': 'Silvia: “Ero una NoVax e credevo a qualsiasi balla”',
#   'Views': '27980'},
#  {'Comments': '125',
#   'Likes': '425',
#   'Published_date': '2022-05-01T07:25:23Z',
#   'Title': 'Festa dei lavoratori 2022: perché si celebra il 1° maggio? La storia che forse non conosci',
#   'Views': '8560'},
#  {'Comments': '15',
#   'Likes': '74',
#   'Published_date': '2022-05-01T07:10:03Z',
#   'Title': 'Bombardieri a Fanpage.it: "Ora basta dare aiuti alle imprese, è il turno di chi è rimasto indietro"',
#   'Views': '2809'},
#  {'Comments': '433',
#   'Likes': '1279',
#   'Published_date': '2022-04-30T14:49:29Z',
#   'Title': "Mino Raiola è morto a 54 anni: l'annuncio ufficiale della famiglia",
#   'Views': '105936'},
#  {'Comments': '11',
#   'Likes': '53',
#   'Published_date': '2022-04-30T14:36:02Z',
#   'Title': 'Violenze nel carcere di Santa Maria, il garante Ciambriello: "Numero sui caschi dei poliziotti"',
#   'Views': '5004'},
#  {'Comments': '38',
#   'Likes': '232',
#   'Published_date': '2022-04-30T13:41:53Z',
#   'Title': 'La funivia del Monte Faito vista dal drone: "Si può ammirare il golfo di Napoli e Sorrento"',
#   'Views': '18563'},
#  {'Comments': '39',
#   'Likes': '106',
#   'Published_date': '2022-04-30T07:10:32Z',
#   'Title': 'Un anno senza Saman: dal "no" alle nozze combinate all\'ultimo sms, fino alla legge col suo nome',
#   'Views': '7495'},
#  {'Comments': '7',
#   'Likes': '52',
#   'Published_date': '2022-04-30T06:55:37Z',
#   'Title': 'Commemorazione per Antonio Prisco, il sindacalista napoletano dei riders: "La lotta continua"',
#   'Views': '2717'},
#  {'Comments': '616',
#   'Likes': '562',
#   'Published_date': '2022-04-30T06:53:16Z',
#   'Title': 'La marcia nera di Milano: saluti romani per Sergio Ramelli e uno striscione "onore ai camerati cadut',
#   'Views': '21793'},
#  {'Comments': '286',
#   'Likes': '1273',
#   'Published_date': '2022-04-29T19:36:20Z',
#   'Title': '"Ultimamente era diversa", parla un\'amica della donna che ha ucciso il vicino di casa a Treviglio',
#   'Views': '124062'},
#  {'Comments': '1',
#   'Likes': '55',
#   'Published_date': '2022-04-29T18:53:18Z',
#   'Title': 'Conservatorio, scontro tra il direttore e gli studenti: “Malagestione” La replica: “Querelo”',
#   'Views': '3398'},
#  {'Comments': '89',
#   'Likes': '201',
#   'Published_date': '2022-04-29T17:13:29Z',
#   'Title': 'Eva Henger e Massimiliano Caroletti coinvolti in un grave incidente d’auto, le condizioni',
#   'Views': '44036'},
#  {'Comments': '120',
#   'Likes': '524',
#   'Published_date': '2022-04-29T17:11:17Z',
#   'Title': 'Uccide per “frustrazione” il bambino di un anno che voleva adottare',
#   'Views': '36622'},
#  {'Comments': '8',
#   'Likes': '93',
#   'Published_date': '2022-04-29T15:16:45Z',
#   'Title': 'Se non sai dire come ti senti... chiedilo al poeta!',
#   'Views': '2472'},
#  {'Comments': '66',
#   'Likes': '289',
#   'Published_date': '2022-04-29T14:52:30Z',
#   'Title': 'Fabio Palotti, l’operaio morto nell’ascensore alla Farnesina: "Nessuno nessuno se n\'era accorto"',
#   'Views': '33798'},
#  {'Comments': '38',
#   'Likes': '142',
#   'Published_date': '2022-04-29T14:50:19Z',
#   'Title': 'Bastoni papà di Azzurra, se avrà un’altra figlia la chiamerà Nera: “Così avremo Nera-Azzurra”',
#   'Views': '8094'},
#  {'Comments': '96',
#   'Likes': '286',
#   'Published_date': '2022-04-29T14:27:47Z',
#   'Title': 'Ucraina, l\'Odissea di Mario fuggito da Kharkiv: "Ci bombardavano casa, bevevamo l\'acqua dalla neve"',
#   'Views': '13709'},
#  {'Comments': '243',
#   'Likes': '185',
#   'Published_date': '2022-04-29T12:53:01Z',
#   'Title': 'Giorgia Meloni a Milano per l\'anniversario di Ramelli: "Il saluto romano è antistorico, non siamo no',
#   'Views': '12982'},
#  {'Comments': '20',
#   'Likes': '430',
#   'Published_date': '2022-04-29T11:59:11Z',
#   'Title': "La classifica dei segni più fortunati della settimana dal 2 all'8 maggio 2022",
#   'Views': '15105'},
#  {'Comments': '378',
#   'Likes': '1205',
#   'Published_date': '2022-04-29T11:32:53Z',
#   'Title': 'Lily\xa0Peters uccisa a 10 anni, arrestato 14enne: “L’ha stuprata e poi strangolata”',
#   'Views': '80916'},
#  {'Comments': '26',
#   'Likes': '90',
#   'Published_date': '2022-04-29T10:31:21Z',
#   'Title': 'Primo caso confermato di trasmissione all’uomo di aviaria H5N1 negli Stati Uniti',
#   'Views': '6271'},
#  {'Comments': '343',
#   'Likes': '920',
#   'Published_date': '2022-04-29T09:47:07Z',
#   'Title': 'L’anziana che ha ucciso il vicino aveva bastonato in passato la moglie: la donna è fuori pericolo',
#   'Views': '91979'},
#  {'Comments': '147',
#   'Likes': '558',
#   'Published_date': '2022-04-29T05:05:42Z',
#   'Title': 'La Russia ha schierato delfini addestrati per proteggere la base di Sebastopoli nel Mar Nero',
#   'Views': '27274'},
#  {'Comments': '208',
#   'Likes': '547',
#   'Published_date': '2022-04-28T16:18:28Z',
#   'Title': 'La petizione per rimuovere Amber Heard da Aquaman 2: “Non si glorifica una molestatrice”',
#   'Views': '21872'},
#  {'Comments': '933',
#   'Likes': '380',
#   'Published_date': '2022-04-28T14:39:31Z',
#   'Title': 'Prorogato l’obbligo di mascherine al chiuso fino al 15 giugno: ecco dove bisogna usarle',
#   'Views': '69718'},
#  {'Comments': '10',
#   'Likes': '270',
#   'Published_date': '2022-04-28T14:31:53Z',
#   'Title': "Delfini addestrati come 'spie', ma perché? #shorts",
#   'Views': '7732'},
#  {'Comments': '643',
#   'Likes': '2214',
#   'Published_date': '2022-04-28T14:23:13Z',
#   'Title': "Anziana spara al vicino e lo uccide, poi ferisce la moglie. L'omicidio di Treviglio ripreso in un vi",
#   'Views': '168155'},
#  {'Comments': '22',
#   'Likes': '190',
#   'Published_date': '2022-04-28T13:42:08Z',
#   'Title': '400mila euro per le donne in Piemonte che decidono di non abortire #shorts',
#   'Views': '7392'},
#  {'Comments': '13',
#   'Likes': '34',
#   'Published_date': '2022-04-28T12:34:15Z',
#   'Title': '"Camorra immobiliare", Manfredi: "Subito intervento interforze contro i clan e serve nuovo piano cas',
#   'Views': '1898'},
#  {'Comments': '394',
#   'Likes': '3301',
#   'Published_date': '2022-04-28T11:31:54Z',
#   'Title': 'Radu scoppia a piangere, i compagni lo salvano dalle telecamere: “Andate via!”',
#   'Views': '212425'},
#  {'Comments': '253',
#   'Likes': '965',
#   'Published_date': '2022-04-28T10:08:07Z',
#   'Title': 'Si inietta cocaina nel pene e va in ospedale, il medico: “Organo ulcerato e gonfio, odore nauseante”',
#   'Views': '63193'},
#  {'Comments': '1103',
#   'Likes': '6038',
#   'Published_date': '2022-04-28T09:05:12Z',
#   'Title': 'Bimbo di 6 anni bruciato da un bullo, le strazianti foto in ospedale: “Mamma mi hanno dato fuoco”',
#   'Views': '245553'},
#  {'Comments': '15',
#   'Likes': '85',
#   'Published_date': '2022-04-28T08:41:33Z',
#   'Title': 'Una casa capovolta sfida ogni legge di gravità: il mondo sottosopra della "Casa Loca di Guatavita"',
#   'Views': '6308'},
#  {'Comments': '35',
#   'Likes': '34',
#   'Published_date': '2022-04-28T05:35:23Z',
#   'Title': 'Giarrusso a Fanpage.it: "Giusto potersi difendere da guerra, ma non si risolverà solo mandando armi"',
#   'Views': '1604'},
#  {'Comments': '502',
#   'Likes': '237',
#   'Published_date': '2022-04-27T16:57:59Z',
#   'Title': '“Ai figli i cognomi di entrambi i genitori”: la sentenza della Consulta',
#   'Views': '18637'},
#  {'Comments': '91',
#   'Likes': '184',
#   'Published_date': '2022-04-27T16:55:51Z',
#   'Title': 'Temptation Island cancellato: sparisce dall’estate di Canale 5 il reality con Filippo Bisciglia',
#   'Views': '10060'},
#  {'Comments': '45',
#   'Likes': '226',
#   'Published_date': '2022-04-27T16:10:58Z',
#   'Title': 'Va dalla zia ma sparisce nel nulla, Lily Peters uccisa a 10 anni lungo il sentiero vicino casa',
#   'Views': '22829'},
#  {'Comments': '292',
#   'Likes': '139',
#   'Published_date': '2022-04-27T15:28:34Z',
#   'Title': 'Ucraina, Salvini: "Chiedo un tavolo con Draghi e i leader di tutti i partiti per parlare di pace"',
#   'Views': '6000'},
#  {'Comments': '271',
#   'Likes': '260',
#   'Published_date': '2022-04-27T15:08:46Z',
#   'Title': 'Francesco si laurea indossando tacchi rossi: "Messaggio ai senatori che hanno affossato il ddl Zan"',
#   'Views': '13170'},
#  {'Comments': '9',
#   'Likes': '243',
#   'Published_date': '2022-04-27T13:09:22Z',
#   'Title': 'Samantha Cristoforetti torna nello spazio #shorts',
#   'Views': '5170'},
#  {'Comments': '538',
#   'Likes': '1225',
#   'Published_date': '2022-04-27T11:57:09Z',
#   'Title': 'La picchiano e le tagliano i capelli, il video dell’orrore sulle chat Telegram: “Ferma o ti uccido”',
#   'Views': '148329'},
#  {'Comments': '15',
#   'Likes': '138',
#   'Published_date': '2022-04-27T11:43:09Z',
#   'Title': "L'amicizia tra Radhika e Mithu, il pappagallo che ogni mattina visita il balcone della sua amica",
#   'Views': '5578'},
#  {'Comments': '208',
#   'Likes': '707',
#   'Published_date': '2022-04-27T11:19:02Z',
#   'Title': 'Passeggero muore per un attacco di cuore a bordo di un volo diretto a Bergamo',
#   'Views': '122699'},
#  {'Comments': '591',
#   'Likes': '235',
#   'Published_date': '2022-04-27T10:36:31Z',
#   'Title': 'Addio al Green Pass dal 1° maggio, per le mascherine al chiuso probabile proroga di un mese',
#   'Views': '31624'},
#  {'Comments': '48',
#   'Likes': '275',
#   'Published_date': '2022-04-27T09:38:49Z',
#   'Title': 'Alessandro Venturelli scomparso, la madre: "Ho paura non sia libero di tornare a casa"',
#   'Views': '15215'},
#  {'Comments': '136',
#   'Likes': '204',
#   'Published_date': '2022-04-27T09:22:46Z',
#   'Title': 'Samantha Cristoforetti è in viaggio verso la Stazione Spaziale Internazionale',
#   'Views': '7367'},
#  {'Comments': '183',
#   'Likes': '163',
#   'Published_date': '2022-04-26T16:41:45Z',
#   'Title': 'Ai Me contro Te con Il Film Il Mistero della Scuola Incantata va il David dello Spettatore 2022',
#   'Views': '11052'},
#  {'Comments': '194',
#   'Likes': '411',
#   'Published_date': '2022-04-26T15:46:34Z',
#   'Title': "“Amber va bruciata viva”: i messaggi inviati da Johnny Depp all'amico Paul Bettany",
#   'Views': '27687'},
#  {'Comments': '5',
#   'Likes': '36',
#   'Published_date': '2022-04-26T14:53:35Z',
#   'Title': 'Futuro dell\'Europa, i giovani presentano le loro proposte. Amendola: "Ora l\'Ue deve cambiare"',
#   'Views': '1903'},
#  {'Comments': '221',
#   'Likes': '242',
#   'Published_date': '2022-04-26T14:42:37Z',
#   'Title': 'Milano, al 25 Aprile urla contro il Pd e le bandiere della Nato: "Ci stanno portando in guerra"',
#   'Views': '10836'},
#  {'Comments': '427',
#   'Likes': '2806',
#   'Published_date': '2022-04-26T14:40:00Z',
#   'Title': 'Trovato senza vita Ahmed Joudier, il cadavere del 15enne ripescato nel fiume Brenta a Padova',
#   'Views': '176030'},
#  {'Comments': '73',
#   'Likes': '160',
#   'Published_date': '2022-04-26T13:23:19Z',
#   'Title': 'Napoli, il racket della camorra sulle case popolari: "Mille euro per entrare negli alloggi"',
#   'Views': '38301'},
#  {'Comments': '20',
#   'Likes': '44',
#   'Published_date': '2022-04-26T12:48:05Z',
#   'Title': 'Fedez torna a X Factor, sarà giudice per la sesta volta: “Si torna a casa”',
#   'Views': '3977'},
#  {'Comments': '21',
#   'Likes': '23',
#   'Published_date': '2022-04-26T11:54:41Z',
#   'Title': 'Misiani (PD): "Aumentiamo tasse sugli extraprofitti, bisogna evitare terza recessione in dieci anni"',
#   'Views': '1591'},
#  {'Comments': '80',
#   'Likes': '111',
#   'Published_date': '2022-04-26T11:39:52Z',
#   'Title': 'Lulù Selassié parla della rottura con Manuel: “Terze persone ci hanno messo contro”',
#   'Views': '13216'},
#  {'Comments': '17',
#   'Likes': '198',
#   'Published_date': '2022-04-26T10:25:55Z',
#   'Title': "Fast food solidale a un euro: nasce a Caltanissetta l'iniziativa contro la povertà",
#   'Views': '9500'},
#  {'Comments': '1957',
#   'Likes': '2071',
#   'Published_date': '2022-04-26T09:58:24Z',
#   'Title': 'Lavrov dice che la terza guerra mondiale nucleare si sta avvicinando',
#   'Views': '209931'},
#  {'Comments': '55',
#   'Likes': '67',
#   'Published_date': '2022-04-26T09:56:01Z',
#   'Title': 'Elon Musk ha comprato Twitter, l’operazione vale 44 miliardi di dollari',
#   'Views': '3033'},
#  {'Comments': '63',
#   'Likes': '116',
#   'Published_date': '2022-04-26T09:07:02Z',
#   'Title': 'Il vessillo per Ugo Russo sfila dopo le polemiche: "Non è una sfida, ma un modo per ricordarlo"',
#   'Views': '5640'},
#  {'Comments': '2042',
#   'Likes': '1399',
#   'Published_date': '2022-04-25T18:36:28Z',
#   'Title': 'Milano, al corteo del 25 aprile i pro separatisti del Donbass: "Noi con la Russia, Putin ci difende"',
#   'Views': '51052'},
#  {'Comments': '378',
#   'Likes': '346',
#   'Published_date': '2022-04-25T16:41:36Z',
#   'Title': '25 Aprile a Roma nel segno dell\'Ucraina, ma l\'ala dura del corteo: "Quella non è Resistenza"',
#   'Views': '15297'},
#  {'Comments': '52',
#   'Likes': '109',
#   'Published_date': '2022-04-25T15:54:42Z',
#   'Title': '"Questo è un 25 aprile diverso": per la festa della Liberazione si torna a Monte Sole (Bologna)',
#   'Views': '3282'},
#  {'Comments': '118',
#   'Likes': '108',
#   'Published_date': '2022-04-25T13:46:13Z',
#   'Title': 'Napoli, corteo del 25 aprile contro la guerra: "Con gli ucraini solidarietà di popolo"',
#   'Views': '4777'},
#  {'Comments': '241',
#   'Likes': '146',
#   'Published_date': '2022-04-25T11:00:35Z',
#   'Title': '25 Aprile, Manfredi: "Via i ritratti di Mussolini dagli uffici comunali, importante la cultura della',
#   'Views': '8975'},
#  {'Comments': '180',
#   'Likes': '193',
#   'Published_date': '2022-04-25T08:53:28Z',
#   'Title': 'Roman O\'Leg si prepara a combattere: "Ci insegnano come non suicidarci o uccidere senza motivo"',
#   'Views': '10076'},
#  {'Comments': '62',
#   'Likes': '210',
#   'Published_date': '2022-04-25T07:05:39Z',
#   'Title': '25 aprile, l’intervista al partigiano Lampino: “Vi racconto la mia vita in clandestinità”',
#   'Views': '6224'},
#  {'Comments': '1190',
#   'Likes': '2839',
#   'Published_date': '2022-04-25T06:20:12Z',
#   'Title': '25 aprile Festa della Liberazione: chi erano i partigiani e come hanno combattuto il fascismo',
#   'Views': '60689'},
#  {'Comments': '642',
#   'Likes': '371',
#   'Published_date': '2022-04-24T19:08:58Z',
#   'Title': 'Emmanuel Macron vince le elezioni presidenziali in Francia contro Marine Le Pen',
#   'Views': '16680'},
#  {'Comments': '124',
#   'Likes': '181',
#   'Published_date': '2022-04-24T17:03:22Z',
#   'Title': 'La Pasqua della comunità ucraina a Roma: “Preghiamo per i nostri cari in guerra”',
#   'Views': '7335'},
#  {'Comments': '486',
#   'Likes': '308',
#   'Published_date': '2022-04-24T14:31:31Z',
#   'Title': 'Misteriosa epatite nei bambini, l’Oms: "1 morto e 17 trapianti di fegato in 12 Paesi"',
#   'Views': '29676'},
#  {'Comments': '120',
#   'Likes': '247',
#   'Published_date': '2022-04-24T11:33:24Z',
#   'Title': 'Ansia per Stefano Tacconi, ricoverato per ischemia: “Riprenditi, papi, sei un leone”',
#   'Views': '25153'},
#  {'Comments': '413',
#   'Likes': '471',
#   'Published_date': '2022-04-24T10:31:08Z',
#   'Title': 'Odessa, morte la giornalista Valeria Glodan e la figlia di 3 mesi: bombe russe sulla loro casa',
#   'Views': '44958'},
#  {'Comments': '934',
#   'Likes': '294',
#   'Published_date': '2022-04-24T09:39:38Z',
#   'Title': 'Zelensky: “I russi sono terroristi bas***di, stanno deportando gli abitanti di Mariupol in Siberia”',
#   'Views': '19834'},
#  {'Comments': '149',
#   'Likes': '535',
#   'Published_date': '2022-04-24T08:57:23Z',
#   'Title': 'LDA eliminato da Amici di Maria De Filippi scoppia in lacrime: “Mi avete migliorato”',
#   'Views': '98680'},
#  ...]

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                    Title  \
# 0      Perché Ryanair non venderà più biglietti scont...
# 1      Intrappolato 8 ore in un tunnel sottoterra: fo...
# 2           5 modi per combattere ansia e stress #shorts
# 3      LucyLein a Fanpage: "Senza fare porno, guadagn...
# 4      Maria De Filippi: “Non so se avrò la forza di ...
# ...                                                  ...
# 19928  Chiara Ferragni incinta da tre mesi di Fedez, ...
# 19929  Test di ingresso a Medicina, protesta degli st...
# 19930  Tutto quello che sappiamo sull'iPhone 8 (in 60...
# 19931  Napoli, rom trasferiti nella caserma. Blocco s...
# 19932  Artrite reumatoide, svolta storica: medici ita...
#
#              Published_date   Views Likes Comments
# 0      2022-08-12T05:00:19Z    2140    36       11
# 1      2022-08-11T20:25:26Z   10497   134       87
# 2      2022-08-11T19:30:03Z    1734   107       11
# 3      2022-08-11T18:00:30Z   17188   587      357
# 4      2022-08-11T17:00:29Z   21185   171       50
# ...                     ...     ...   ...      ...
# 19928  2017-09-05T17:21:55Z  165826  2861      219
# 19929  2017-09-05T16:26:49Z    8087   187       37
# 19930  2017-09-05T15:50:49Z   93496  1892      672
# 19931  2017-09-05T14:51:51Z    9952   163       72
# 19932  2017-09-05T13:23:46Z    8760   200       17
#
# [19933 rows x 5 columns]

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data
# Out:
#                                                    Title Published_date  \
# 0      Perché Ryanair non venderà più biglietti scont...     2022-08-12
# 1      Intrappolato 8 ore in un tunnel sottoterra: fo...     2022-08-11
# 2           5 modi per combattere ansia e stress #shorts     2022-08-11
# 3      LucyLein a Fanpage: "Senza fare porno, guadagn...     2022-08-11
# 4      Maria De Filippi: “Non so se avrò la forza di ...     2022-08-11
# ...                                                  ...            ...
# 19928  Chiara Ferragni incinta da tre mesi di Fedez, ...     2017-09-05
# 19929  Test di ingresso a Medicina, protesta degli st...     2017-09-05
# 19930  Tutto quello che sappiamo sull'iPhone 8 (in 60...     2017-09-05
# 19931  Napoli, rom trasferiti nella caserma. Blocco s...     2017-09-05
# 19932  Artrite reumatoide, svolta storica: medici ita...     2017-09-05
#
#         Views  Likes Comments
# 0        2140     36       11
# 1       10497    134       87
# 2        1734    107       11
# 3       17188    587      357
# 4       21185    171       50
# ...       ...    ...      ...
# 19928  165826   2861      219
# 19929    8087    187       37
# 19930   93496   1892      672
# 19931    9952    163       72
# 19932    8760    200       17
#
# [19933 rows x 5 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                    Title Published_date  \
# 12401  Rapinatore gli punta il fucile al petto e lui ...     2019-09-13
# 18018  Dedicare una canzone alle prostitute: l'esperi...     2018-03-08
# 12990       Le 10 scuse di Lorenzo per non fare il bagno     2019-07-25
# 12498  Telefonata truffa, per sbaglio chiamano la pol...     2019-09-06
# 17597  Arriva alla cassa ma non ha soldi per pane e l...     2018-04-19
# 16255  Prof razzista attacca studentessa musulmana. L...     2018-09-18
# 19528  Uomo di 45 anni sposa bambina di 12 anni: le r...     2017-10-10
# 14988  Salveresti la vita a un immigrato? [ESPERIMENT...     2019-02-19
# 12886  Sta per soffocare per un boccone di traverso. ...     2019-08-01
# 14600  "Mamma mi diede in sposa a un orco, in grembo ...     2019-03-29
#
#          Views   Likes Comments
# 12401  9666771  123046     4978
# 18018  7743223  212607     6971
# 12990  7487291   80803     1928
# 12498  7183166  155820     1706
# 17597  7172499  104922     5170
# 16255  6131795  160340     9593
# 19528  5989534   88811     3359
# 14988  5645767  221212    12056
# 12886  5341251   46614     1984
# 14600  4878899   85431     2912

# %% [markdown]
# #Fanpage most viewed videos (TOP10)

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# #Adding 'Year' column

# %%
video_data['Year'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%Y')

# %%
video_data
# Out:
#                                                    Title Published_date  \
# 0      Ha 42 anni, da 7 non trova lavoro, laureata e ...     2022-06-17
# 1      Attore di Riverdale uccide la madre, il suo pe...     2022-06-17
# 2      Bruno Pereira e Dom Phillips trovati morti, er...     2022-06-17
# 3      Milano, nelle case Aler abusivi nei box, urina...     2022-06-17
# 4      La classifica dei segni più fortunati della se...     2022-06-17
# ...                                                  ...            ...
# 19478  Tutto quello che sappiamo sull'iPhone 8 (in 60...     2017-09-05
# 19479  Napoli, rom trasferiti nella caserma. Blocco s...     2017-09-05
# 19480  Artrite reumatoide, svolta storica: medici ita...     2017-09-05
# 19481  Bimba morta di Malaria: "In ospedale c'erano d...     2017-09-05
# 19482  Sofia, morta di malaria a 4 anni. L'esperto: "...     2017-09-05
#
#         Views  Likes Comments  Year
# 0       40380    498      416  2022
# 1       19647    271       77  2022
# 2      121467    851      123  2022
# 3      101541    646      312  2022
# 4       43733    493       30  2022
# ...       ...    ...      ...   ...
# 19478   93496   1892      672  2017
# 19479    9952    163       72  2017
# 19480    8759    200       17  2017
# 19481   20689    339      161  2017
# 19482    4466     60       26  2017
#
# [19483 rows x 6 columns]

# %%
videos_per_year = video_data.groupby('Year', as_index=False).size()

# %%
videos_per_year
# Out:
#    Year  size
# 0  2017  1220
# 1  2018  3338
# 2  2019  4506
# 3  2020  4886
# 4  2021  3776
# 5  2022  1757

# %%
videos_per_year.index = pd.CategoricalIndex(videos_per_year['Year'], categories=videos_per_year['Year'], ordered=True)

# %%
videos_per_year = videos_per_year.sort_index()

# %% [markdown]
# #Views per year

# %%
ax2 = sns.barplot(x='Year', y='size', data=videos_per_year)

# %%
video_data.to_csv('Video_Details(Fanpage.csv)') #saving results
